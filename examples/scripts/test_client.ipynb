# %%
# Import packages from the Python standard library
import importlib.util
import os
import sys
import pprint
import time
import warnings
from pathlib import Path


def register_python_source_file(module_name: str, filepath: Path) -> None:
    """Import a source file directly.

    Args:
        module_name: The module name to associate with the imported source file.
        filepath: The path to the source file.

    Notes:
        Adapted from the following implementation in the Python documentation:
        https://docs.python.org/3/library/importlib.html#importing-a-source-file-directly
    """
    spec = importlib.util.spec_from_file_location(module_name, str(filepath))
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    spec.loader.exec_module(module)


# Filter out warning messages
warnings.filterwarnings("ignore")

# Experiment name
EXPERIMENT_NAME = "mnist"

# Default address for accessing the RESTful API service
RESTAPI_ADDRESS = "http://localhost:5000"

# Set DIOPTRA_RESTAPI_URI variable if not defined, used to connect to RESTful API service
os.environ["DIOPTRA_RESTAPI_URI"] = RESTAPI_ADDRESS

# Default address for accessing the MLFlow Tracking server
MLFLOW_TRACKING_URI = "http://localhost:35000"

# Set MLFLOW_TRACKING_URI variable, used to connect to MLFlow Tracking service
if os.getenv("MLFLOW_TRACKING_URI") is None:
    os.environ["MLFLOW_TRACKING_URI"] = MLFLOW_TRACKING_URI

# Path to workflows archive
WORKFLOWS_TAR_GZ = Path("workflows.tar.gz")

# Register the examples/scripts directory as a Python module
register_python_source_file("scripts", Path("..", "scripts", "__init__.py"))

#from scripts.client import DioptraClient
from scripts.utils import make_tar

# Import third-party Python packages
import numpy as np
from mlflow.tracking import MlflowClient

# Create random number generator
rng = np.random.default_rng(54399264723942495723666216079516778448)

# %%
from __future__ import annotations

import os
from pathlib import Path
from posixpath import join as urljoin
from typing import Any
from urllib.parse import urlparse, urlunparse
import inspect
import requests
from typing import Any, cast

import structlog
from structlog.stdlib import BoundLogger

LOGGER: BoundLogger = structlog.stdlib.get_logger()

class APIConnectionError(Exception):
    '''Class for connection errors'''
class StatusCodeError(Exception):
    '''Class for status code errors'''
class JSONDecodeError(Exception):
    '''Class for JSON decode errors'''

def create_data_dict(**kwargs):
    return kwargs

def debug_request(url, method, data=None):
    LOGGER.debug("Request made.", url=url, method=method, data=data)
def debug_response(json):
    LOGGER.debug("Response received.", json=json)

def get(session, endpoint, *features):
    debug_request(urljoin(endpoint, *features), 'GET')
    return make_request(session, 'get', endpoint, None, *features)
def post(session, endpoint, data, *features):
    debug_request(urljoin(endpoint, *features), 'POST', data)
    return make_request(session, 'post', endpoint, data, *features)
def delete(session, endpoint, data, *features):
    debug_request(urljoin(endpoint, *features), 'DELETE', data)
    return make_request(session, 'delete', endpoint, data, *features)
def put(session, endpoint, data, *features):
    debug_request(urljoin(endpoint, *features), 'PUT', data)
    return make_request(session, 'put', endpoint, data, *features)

def make_request(session, method_name, endpoint, data, *features):
    url = urljoin(endpoint, *features)
    method = getattr(session, method_name)
    try: 
        if (data):
            response = method(url, json=data)
        else:
            response = method(url)
        if response.status_code != 200:
            raise StatusCodeError() 
        json = response.json()
    except (requests.ConnectionError, StatusCodeError, requests.JSONDecodeError) as e:
        handle_error(session, url, method_name.upper(), data, response, e) 
    debug_response(json=json)
    return json

def handle_error(session, url, method, data, response, error):
    if (type(error) is requests.ConnectionError):
        restapi = os.environ["DIOPTRA_RESTAPI_URI"]
        message = f"Could not connect to the REST API. Is the server running at {restapi}?"
        LOGGER.error(message, url=url, method=method, data=data, response=response.text);
        raise APIConnectionError(message);
    if (type(error) is StatusCodeError):
        message = f"Error code {response.status_code} returned."
        LOGGER.error(message, url=url, method=method, data=data, response=response.text);
        raise StatusCodeError(message);
    if (type(error) is requests.JSONDecodeError):
        message = f"JSON response could not be decoded."
        LOGGER.error(message, url=url, method=method, data=data, response=response.text);
        raise JSONDecodeError(message);

        

class DioptraClient(object):
    def __init__(self, session, address=None, api_version="v1") -> None:
        self._session = session
        self._users = UsersClient(session, "users", address, api_version)
        self._auth = AuthClient(session, "auth", address, api_version)
        self._queues = QueuesClient(session, "queues", address, api_version)
        self._groups = GroupsClient(session, "groups", address, api_version)
        self._tags = TagsClient(session, "tags", address, api_version)
        self._plugins = PluginsClient(session, "plugins", address, api_version)
        self._pluginParameterTypes = PluginParameterTypesClient(session, "pluginParameterTypes", address, api_version)
        self._experiments = ExperimentsClient(session, "experiments", address, api_version)
        self._jobs = JobsClient(session, "jobs", address, api_version)
        self._entrypoints = EntrypointsClient(session, "entrypoints", address, api_version)
        # models
        # artifacts
    @property
    def users(self):
        return self.get_endpoint(self._users)
    @property
    def auth(self):
        return self.get_endpoint(self._auth)
    @property
    def queues(self):
        return self.get_endpoint(self._queues)
    @property
    def groups(self):
        return self.get_endpoint(self._groups)
    @property
    def tags(self):
        return self.get_endpoint(self._tags)
    @property
    def plugins(self):
        return self.get_endpoint(self._plugins)
    @property
    def pluginParameterTypes(self):
        return self.get_endpoint(self._pluginParameterTypes)
    @property
    def experiments(self):
        return self.get_endpoint(self._experiments)
    @property
    def jobs(self):
        return self.get_endpoint(self._jobs)
    @property
    def entrypoints(self):
        return self.get_endpoint(self._entrypoints)

    def get_endpoint(self, ep):
        ep.session = self._session
        return ep

class Endpoint(object):
    def __init__(self, session, ep_name, address, api_version) -> None:
        address = (
            f"{address}/api/{api_version}"
            if address
            else f"{os.environ['DIOPTRA_RESTAPI_URI']}/api/{api_version}"
        )
        self._scheme, self._netloc, self._path, _, _, _ = urlparse(address)
        self._ep_name = ep_name
        self._session = session
    @property
    def session(self):
        return self._session
    @session.setter
    def session(self, s):
        self._session = s
    @property
    def url(self):
        return self.def_endpoint(self._ep_name)
    def def_endpoint(self, name):
        '''creates base url for an endpoint by name'''
        return urlunparse(
            (self._scheme, self._netloc, urljoin(self._path, name + "/"), "", "", "")
        )

class UsersClient(Endpoint):
    def get_all(self):
        '''gets all users'''
        return get(self.session, self.url)
    def create(self, username, email, password, confirm_password):
        '''creates a user'''
        d = {"username":username,
             "email": email,
             "password": password,
             "confirmPassword": confirm_password}
        return post(self.session, self.url, d)
    def get_by_id(self, user_id):
        '''get a user by id'''
        return get(self.session, self.url, str(user_id))
    def update_password_by_id(self, user_id, old_password, new_password, confirm_new_password):
        '''change a user's password by id'''
        d = {"oldPassword":old_password,
             "newPassword": new_password,
             "confirmNewPassword": confirm_new_password}
        return post(self.session, self.url, d, str(user_id), 'password')
    def current(self):
        '''get the current user'''
        return get(self.session, self.url, 'current')
    def delete_current(self, password):
        '''delete the current user'''
        d = {"password":password}
        return delete(self.session, self.url, d, 'current')
    def modify_current(self, username, email):
        '''modify the current user'''
        d = {"username":username,
             "email": email}
        return put(self.session, self.url, d, 'current')
    def modify_current_password(self, old_password, new_password, confirm_new_password):
        '''modify the current user's password'''
        d = {"oldPassword":old_password,
             "newPassword": new_password,
             "confirmNewPassword": confirm_new_password}
        return post(self.session, self.url, d, 'current', 'password')
    def failed_user_post(self):
        '''create a post request with an invalid schema, for testing'''
        return post(self.session, self.url, {'a':'doesnotexist'})
    def failed_user_get(self):
        '''create a get request to an invalid url, for testing'''
        return get(self.session, self.url, 'doesnotexist')

class AuthClient(Endpoint):
    def login(self, username, password):
        '''login as the given user'''
        d = {"username":username,
             "password": password}
        return post(self.session, self.url, d, 'login')
    def logout(self, everywhere):
        '''logout as the current user'''
        d = {"everywhere": everywhere}
        return post(self.session, self.url, d, 'logout')

class GroupsClient(Endpoint):
    def get_all(self):
        '''get all groups'''
        return get(self.session, self.url)
    def get_by_id(self, gid):
        '''get a group by id'''
        return get(self.session, self.url, str(gid))
        
class QueuesClient(Endpoint):
    def get_all(self):
        '''gets all queues'''
        return get(self.session, self.url)
    def create(self, group, name, description):
        '''create a queue'''
        d = {"group": group,
             "name": name,
             "description": description
            }
        return post(self.session, self.url, d)
    def get_drafts(self):
        '''gets all queue drafts'''
        return get(self.session, self.url, 'drafts')
    def create_draft(self, group, name, description):
        '''create a draft'''
        d = {"group": group,
             "name": name,
             "description": description
            }
        return post(self.session, self.url, d, 'drafts')
    def modify_draft_by_draft_id(self, draft_id, name, description):
        '''modify a draft by id'''
        d = {"name": name,
             "description": description
            }
        return put(self.session, self.url, d, 'drafts', str(draft_id))
    def delete_draft_by_draft_id(self, draft_id):
        '''delete a draft by id'''
        d = None
        return delete(self.session, self.url, d, 'drafts', str(draft_id))
    def get_draft_by_draft_id(self, draft_id):
        '''get a draft by id'''
        return get(self.session, self.url, 'drafts', str(draft_id))
    def modify_by_id(self, queue_id, name, description):
        '''modify a queue by id'''
        d = {"name": name,
             "description": description
            }
        return put(self.session, self.url, d, str(queue_id))
    def delete_by_id(self, queue_id):
        '''delete a queue by id'''
        d = None
        return delete(self.session, self.url, d, str(queue_id))
    def get_by_id(self, queue_id):
        '''get a queue by id'''
        return get(self.session, self.url, str(queue_id))
    def modify_draft_by_queue_id(self, queue_id, name, description):
        '''modify a draft by queue id'''
        d = {"name": name,
             "description": description
            }
        return put(self.session, self.url, d, str(queue_id), 'draft')
    def create_draft_by_queue_id(self, queue_id, name, description):
        '''create a draft by queue id'''
        d = {"name": name,
             "description": description
            }
        return post(self.session, self.url, d, str(queue_id), 'draft')
    def delete_draft_by_queue_id(self, queue_id):
        '''delete a draft by queue id'''
        d = None
        return delete(self.session, self.url, d, str(queue_id), 'draft')
    def get_draft_by_queue_id(self, queue_id):
        '''get a draft by queue id'''
        return get(self.session, self.url, str(queue_id), 'draft')
    
class TagsClient(Endpoint):
    def get_all(self):
        return get(self.session, self.url)
    def create(self, name, group):
        d = {"name": name, 
             "group": group}
        return post(self.session, self.url, d)
    def delete_by_id(self, tag_id):
        d = None
        return delete(self.session, self.url, d, str(tag_id))
    def get_by_id(self, tag_id):
        return get(self.session, self.url, str(tag_id))
    def modify_by_id(self, tag_id, name):
        d = {"name": name}
        return put(self.session, self.url, d, str(tag_id))
    def get_resources_by_id(self, tag_id):
        return get(self.session, self.url, str(tag_id), 'resources')

class EntrypointsClient(Endpoint, HasTagsProvider):
    def __init__(self, session, ep_name, address, api_version) -> None:
        Endpoint.__init__(self, session, ep_name, address, api_version)
        HasTagsProvider.__init__(self, self.url, self.session)
    def get_all(self):
        return get(self.session, self.url)
    def create(self, group, name, description, taskGraph, parameters, queues, plugins):
        d = {
            "group": group,
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues,
            "plugins": plugins
        }
        return post(self.session, self.url, d)
    def create_draft(self, group, name, description, taskGraph, parameters, queues, plugins):
        d = {
            "group": group,
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues,
            "plugins": plugins
        }
        return post(self.session, self.url, d, 'drafts')
    def get_drafts(self):
        return get(self.session, self.url, 'drafts')
    def modify_draft_by_draft_id(self, draft_id, name, description, taskGraph, parameters, queues):
        d = {
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues
        }
        return put(self.session, self.url, d, 'drafts', str(draft_id))
    def get_draft_by_draft_id(self, draft_id):
        return get(self.session, self.url, 'drafts', str(draft_id))
    def delete_draft_by_draft_id(self, draft_id):
        d = None
        return delete(self.session, self.url, d, 'drafts', str(draft_id))
    def modify_by_id(self, entrypoint_id, name, description, taskGraph, parameters, queues):
        d = {
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues
        } 
        return put(self.session, self.url, d, str(entrypoint_id))
    def get_by_id(self, entrypoint_id):
        return get(self.session, self.url, str(entrypoint_id))
    def delete_by_id(self, entrypoint_id):
        d = None
        return delete(self.session, self.url, d, str(entrypoint_id))
    def modify_draft_by_entrypoint_id(self, entrypoint_id, name, description, taskGraph, parameters, queues, plugins):
        d = {
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues,
            "plugins": plugins
        }
        return put(self.session, self.url, d, str(entrypoint_id), 'draft')
    def create_draft_by_entrypoint_id(self, entrypoint_id, name, description, taskGraph, parameters, queues, plugins):
        d = {
            "name": name,
            "description": description,
            "taskGraph": taskGraph,
            "parameters": parameters,
            "queues": queues,
            "plugins": plugins
        }
        return post(self.session, self.url, d, str(entrypoint_id), 'draft')
    def get_draft_by_entrypoint_id(self, entrypoint_id):
        return get(self.session, self.url, str(entrypoint_id), 'draft')
    def delete_draft_by_entrypoint_id(self, entrypoint_id):
        d = None
        return delete(self.session, self.url, d, str(entrypoint_id), 'draft')
    def get_plugins_by_entrypoint_id(self, entrypoint_id):
        return get(self.session, self.url, str(entrypoint_id), 'plugins')
    def add_plugins_by_entrypoint_id(self, entrypoint_id, plugins):
        d = {"plugins": plugins}
        return post(self.session, self.url, d, str(entrypoint_id), 'plugins')
    def get_plugins_by_entrypoint_id_plugin_id(self, entrypoint_id, plugin_id):
        return get(self.session, self.url, str(entrypoint_id), 'plugins', str(plugin_id))
    def delete_plugins_by_entrypoint_id_plugin_id(self, entrypoint_id, plugin_id):
        d = None
        return delete(self.session, self.url, d, str(entrypoint_id), 'plugins', str(plugin_id))
    def modify_queues_by_entrypoint_id(self, entrypoint_id, ids):
        d = { "ids": ids}
        return put(self.session, self.url, d, str(entrypoint_id), 'queues')
    def add_queues_by_entrypoint_id(self, entrypoint_id, ids):
        d = { "ids": ids}
        return post(self.session, self.url, d, str(entrypoint_id), 'queues')
    def get_queues_by_entrypoint_id(self, entrypoint_id):
        return get(self.session, self.url, str(entrypoint_id), 'queues')
    def delete_queues_by_entrypoint_id(self, entrypoint_id):
        d = None
        return delete(self.session, self.url, d, str(entrypoint_id), 'queues')
    def delete_queues_by_entrypoint_id_queue_id(self, entrypoint_id, queue_id):
        d = None
        return delete(self.session, self.url, d, str(entrypoint_id), 'queues', str(queue_id))
    def get_snapshots_by_entrypoint_id(self, entrypoint_id):
        return get(self.session, self.url, str(entrypoint_id), 'snapshots')
    def get_snapshots_by_entrypoint_id_snapshot_id(self, entrypoint_id, snapshot_id):
        return get(self.session, self.url, str(entrypoint_id), 'snapshots', str(snapshot_id))

class ExperimentsClient(Endpoint, HasTagsProvider):
    def __init__(self, session, ep_name, address, api_version) -> None:
        Endpoint.__init__(self, session, ep_name, address, api_version)
        HasTagsProvider.__init__(self, self.url, self.session)
    def get_all(self):
        return get(self.session, self.url)
    def create(self, group, name, description, entrypoints):
        d = {
            "group": group,
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return post(self.session, self.url, d)
    def get_drafts(self):
        return get(self.session, self.url, 'drafts')
    def create_draft(self, group, name, description, entrypoints):
        d = {
            "group": group,
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return post(self.session, self.url, d, 'drafts')
    def get_drafts_by_draft_id(self, draft_id):
        return get(self.session, self.url, 'drafts', str(draft_id))
    def modify_drafts_by_draft_id(self, draft_id, name, description, entrypoints):
        d = {
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return put(self.session, self.url, d, 'drafts', str(draft_id))
    def delete_drafts_by_draft_id(self, draft_id):
        d = None
        return delete(self.session, self.url, d, 'drafts', str(draft_id))
    def get_by_id(self, experiment_id):
        return get(self.session, self.url, str(experiment_id))
    def modify_by_id(self, experiment_id, name, description, entrypoints):
        d = {
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return put(self.session, self.url, d, str(experiment_id))
    def delete_by_id(self, experiment_id):
        d = None
        return delete(self.session, self.url, d, str(experiment_id))
    def get_draft_by_experiment_id(self, experiment_id):
        return get(self.session, self.url, str(experiment_id), 'draft')
    def modify_draft_by_experiment_id(self, experiment_id, name, description, entrypoints):
        d = {
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return put(self.session, self.url, d, str(experiment_id), 'draft')
    def create_draft_by_experiment_id(self, experiment_id, name, description, entrypoints):
        d = {
            "name": name,
            "description": description,
            "entrypoints": entrypoints
        }
        return post(self.session, self.url, d, str(experiment_id), 'draft')
    def delete_draft_by_experiment_id(self, experiment_id):
        d = None
        return delete(self.session, self.url, d, str(experiment_id), 'draft')
    def get_entrypoints_by_experiment_id(self, experiment_id):
        return get(self.session, self.url, str(experiment_id), 'entrypoints')
    def modify_entrypoints_by_experiment_id(self, experiment_id, ids):
        d = { "ids":ids }
        return put(self.session, self.url, d, str(experiment_id), 'entrypoints')
    def add_entrypoints_by_experiment_id(self, experiment_id, ids):
        d = { "ids":ids }
        return post(self.session, self.url, d, str(experiment_id), 'entrypoints')
    def delete_entrypoints_by_experiment_id(self, experiment_id):
        d = None
        return delete(self.session, self.url, d, str(experiment_id), 'entrypoints')
    def delete_entrypoints_by_experiment_id_entrypoint_id(self, experiment_id, entrypoint_id):
        d = None
        return delete(self.session, self.url, d, str(experiment_id), 'entrypoints', str(entrypoint_id))
    def get_jobs_by_experiment_id(self, experiment_id):
        return get(self.session, self.url, str(experiment_id), 'jobs')
    def create_jobs_by_experiment_id(self, experiment_id, description, queue, entrypoint, values, timeout):
        d = { 
            "description": description,
            "queue": queue,
            "entrypoint": entrypoint,
            "values": values,
            "timeout": timeout
        }
        return post(self.session, self.url, d, str(experiment_id), 'jobs')
    def get_jobs_by_experiment_id_job_id(self, experiment_id, job_id):
        return get(self.session, self.url, str(experiment_id), 'jobs', str(job_id))
    def delete_jobs_by_experiment_id_job_id(self, experiment_id, job_id):
        d = None
        return delete(self.session, self.url, d, str(experiment_id), 'jobs', str(job_id))
    def get_jobs_status_by_experiment_id_job_id(self, experiment_id, job_id):
        return get(self.session, self.url, str(experiment_id), 'jobs', str(job_id), 'status')
    def modify_jobs_status_by_experiment_id_job_id(self, experiment_id, job_id, status):
        d = {"status":status}
        return put(self.session, self.url, d, str(experiment_id), 'jobs', str(job_id), 'status')
    def get_snapshots_by_experiment_id(self, experiment_id):
        return get(self.session, self.url, str(experiment_id), 'snapshots')
    def get_snapshots_by_experiment_id_snapshot_id(self, experiment_id, snapshot_id):
        return get(self.session, self.url, str(experiment_id), 'snapshots', str(snapshot_id))

class JobsClient(Endpoint, HasTagsProvider):
    def __init__(self, session, ep_name, address, api_version) -> None:
        Endpoint.__init__(self, session, ep_name, address, api_version)
        HasTagsProvider.__init__(self, self.url, self.session)
    def get_all(self):
        return get(self.session, self.url)
    def delete_by_id(self, job_id):
        d = None
        return delete(self.session, self.url, d, str(job_id))
    def get_by_id(self, job_id):
        return get(self.session, self.url, str(job_id))
    def get_snapshots_by_job_id(self, job_id):
        return get(self.session, self.url, str(job_id), 'snapshots')
    def get_snapshots_by_job_id_snapshot_id(self, job_id, snapshot_id):
        return get(self.session, self.url, str(job_id), 'snapshots', str(snapshot_id))
    def get_status_by_job_id(self, job_id):
        return get(self.session, self.url, str(job_id), 'status')


class PluginsClient(Endpoint, HasTagsProvider):
    def __init__(self, session, ep_name, address, api_version) -> None:
        Endpoint.__init__(self, session, ep_name, address, api_version)
        HasTagsProvider.__init__(self, self.url, self.session)
    def get_all(self):
        return get(self.session, self.url)
    def create(self, group, name, description):
        d = {"group":group, 
             "name":name, 
             "description":description}
        return post(self.session, self.url, d)
    def get_all_drafts(self):
        return get(self.session, self.url, 'drafts')
    def create_draft(self, group, name, description):
        d = {"group":group, 
             "name":name, 
             "description":description}
        return post(self.session, self.url, d, 'drafts')
    def get_draft_by_draft_id(self, plugin_id):
        return get(self.session, self.url, 'drafts', str(plugin_id))
    def modify_draft_by_draft_id(self, plugin_id, name, description):
        d = {"name": name,
             "description": description}
        return put(self.session, self.url, d, 'drafts', str(plugin_id))
    def delete_draft_by_draft_id(self, plugin_id):
        d = None
        return delete(self.session, self.url, d, 'drafts', str(plugin_id))
    def get_by_id(self, plugin_id):
        return get(self.session, self.url, str(plugin_id))
    def modify_by_id(self, plugin_id, name, description):
        d = {"name": name,
             "description": description}
        return put(self.session, self.url, d, str(plugin_id))
    def delete_by_id(self, plugin_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id))
    def get_draft_by_plugin_id(self, plugin_id):
        return get(self.session, self.url, str(plugin_id), 'draft')
    def modify_draft_by_plugin_id(self, plugin_id, name, description):
        d = {"name": name,
             "description": description}
        return put(self.session, self.url, d, str(plugin_id), 'draft')
    def create_draft_by_plugin_id(self, plugin_id, name, description):
        d = {"name": name,
             "description": description}
        return post(self.session, self.url, d, str(plugin_id), 'draft')
    def delete_draft_by_plugin_id(self, plugin_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'draft')
    def get_files_by_plugin_id(self, plugin_id):
        return get(self.session, self.url, str(plugin_id), 'files')
    def create_files_by_plugin_id(self, plugin_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return post(self.session, self.url, d, str(plugin_id), 'files')
    def delete_files_by_plugin_id(self, plugin_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files')
    def get_files_drafts_by_plugin_id(self, plugin_id):
        return get(self.session, self.url, str(plugin_id), 'files', 'drafts')
    def create_files_drafts_by_plugin_id(self, plugin_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return post(self.session, self.url, d, str(plugin_id), 'files', 'drafts')
    def get_files_drafts_by_plugin_id_draft_id(self, plugin_id, drafts_id):
        return get(self.session, self.url, str(plugin_id), 'files', 'drafts', str(drafts_id))
    def modify_files_drafts_by_plugin_id_draft_id(self, plugin_id, drafts_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return put(self.session, self.url, d, str(plugin_id), 'files', 'drafts', str(drafts_id))
    def delete_files_drafts_by_plugin_id_draft_id(self, plugin_id, drafts_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files', 'drafts', str(drafts_id))
    def get_files_by_plugin_id_file_id(self, plugin_id, file_id):
        return get(self.session, self.url, str(plugin_id), 'files', str(file_id))
    def modify_files_by_plugin_id_file_id(self, plugin_id, file_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return put(self.session, self.url, d, str(plugin_id), 'files', str(file_id))
    def delete_files_by_plugin_id_file_id(self, plugin_id, file_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files', str(file_id))
    def get_files_draft_by_plugin_id_file_id(self, plugin_id, file_id):
        return get(self.session, self.url, str(plugin_id), 'files', str(file_id), 'draft')
    def modify_files_draft_by_plugin_id_file_id(self, plugin_id, file_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return put(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'draft')
    def delete_files_draft_by_plugin_id_file_id(self, plugin_id, file_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'draft')
    def create_files_draft_by_plugin_id_file_id(self, plugin_id, file_id, filename, contents, description, *plugins):
        d = {"filename": filename,
             "contents": contents,
             "description": description,
             "tasks": [plugin.as_dict() for plugin in plugins]
            }
        return post(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'draft')
    def get_snapshots_by_plugin_id_file_id(self, plugin_id, file_id):
        return get(self.session, self.url, str(plugin_id), 'files', str(file_id), 'snapshots')
    def get_snapshots_by_plugin_id_file_id_snapshot_id(self, plugin_id, file_id, snapshot_id):
        return get(self.session, self.url, str(plugin_id), 'files', str(file_id), 'snapshots', str(snapshot_id))
    def get_tags_by_plugin_id_file_id(self, plugin_id, file_id):
        return get(self.session, self.url, str(plugin_id), 'files', str(file_id), 'tags')
    def modify_tags_by_plugin_id_file_id(self, plugin_id, file_id, ids):
        d = {"ids":ids}
        return put(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'tags')
    def delete_tags_by_plugin_id_file_id(self, plugin_id, file_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'tags')
    def add_tags_by_plugin_id_file_id(self, plugin_id, file_id, ids):
        d = {"ids":ids}
        return post(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'tags')
    def delete_tags_by_plugin_id_file_id_tag_id(self, plugin_id, file_id, tag_id):
        d = None
        return delete(self.session, self.url, d, str(plugin_id), 'files', str(file_id), 'tags', str(tag_id))
    def get_snapshots_by_plugin_id(self, plugin_id):
        return get(self.session, self.url, str(plugin_id), 'snapshots')
    def get_snapshot_by_plugin_id_snapshot_id(self, plugin_id, snapshot_id):
        return get(self.session, self.url, str(plugin_id), 'snapshots', str(snapshot_id))

class PluginParameterTypesClient(Endpoint):
    def get_all(self):
        return get(self.session, self.url)
    def create(self, group, name, description, structure):
        d = {"group": group,
             "name": name,
             "description": description,
             "structure": structure}
        return post(self.session, self.url, d)
    def get_by_id(self, type_id):
        return get(self.session, self.url, str(type_id))
    def modify_by_id(self, type_id, name, description, structure):
        d = {"name": name,
             "description": description,
             "structure": structure}
        return put(self.session, self.url, d, str(type_id))
    def delete_by_id(self, type_id):
        d = None
        return delete(self.session, self.url, d, str(type_id))

class PluginTask(object):
    def __init__(self, name, inputs, outputs, client):
        self.name = name
        self.inputs = inputs # expects [(name1, type1), (name2, type2) ...]
        self.outputs = outputs # expects [(name1, type1), (name2, type2) ...]
        self.client = client
    def convert_params_to_ids(self, mappings):
        '''this converts parameters to registered ids using a mapping from register_unregistered_types'''
        return [(i[0], mappings[i[1]]) for i in self.inputs], [(o[0], mappings[o[1]]) for o in self.outputs]
    def register_unregistered_types(self, group=1):
        '''checks all the types in inputs/outputs and register things that aren't registered'''
        registered_types = self.client.pluginParameterTypes.get_all() # get all registered types
        types_used_in_plugin = set([m[1] for m in self.inputs] + [m[1] for m in self.outputs]) # get all types for this plugin
        types_to_id = {}
        for registered in registered_types['data']: # add registered types to our dictionary
            types_to_id[str(registered['name'])] = str(registered['id'])
        for used in types_used_in_plugin:
            used = str(used)
            if (used not in types_to_id): # not yet registered, so register it
                response = self.client.pluginParameterTypes.create(group, used, used + " plugin parameter", structure={})
                types_to_id[used] = str(response['id'])
        return types_to_id # mapping of types to ids
    def as_dict(self, mappings=None):
        '''convert it to a dict to be sent to the RESTAPI'''
        if mappings is None:
            mappings = self.register_unregistered_types()
        ins, outs = self.convert_params_to_ids(mappings)
        return {
            "name": self.name,
            "inputParams": [{"name": param[0], "parameterType": param[1]} for param in ins],
            "outputParams": [{"name": param[0], "parameterType": param[1]} for param in outs]
        }

class HasTagsProvider(object):
    def __init__(self, url, session):
        self._tags = TagsProvider(url, session)
    @property
    def tags(self):
        return self._tags

class TagsProvider(object):
    def __init__(self, base_url, session):
        self.url = base_url 
        self.session = session
    def get(self, parent_id):
        return get(self.session, self.url, str(parent_id), 'tags')
    def modify(self, parent_id, ids):
        d = {"ids":ids}
        return put(self.session, self.url, d, str(parent_id), 'tags')
    def delete_all(self, parent_id):
        d = None
        return delete(self.session, self.url, d, str(parent_id), 'tags')
    def add(self, parent_id, ids):
        d = {"ids":ids}
        return post(self.session, self.url, d, str(parent_id), 'tags')
    def delete(self, parent_id, tag_id):
        d = None
        return delete(self.session, self.url, d, str(parent_id), 'tags', str(tag_id))

# %%
client = DioptraClient(requests.Session())

# %%
def delete_all():
    for d in client.experiments.get_all()['data']:
        client.experiments.delete_by_id(d['id'])
    for d in client.entrypoints.get_all()['data']:
         client.entrypoints.delete_by_id(d['id'])
    for d in client.jobs.get_all()['data']:
         client.jobs.delete_by_id(d['id'])
    for d in client.plugins.get_all()['data']:
        try:
            client.plugins.delete_by_id(d['id'])
        except:
            pass
    for d in client.tags.get_all()['data']:
         client.tags.delete_by_id(d['id'])
    for d in client.pluginParameterTypes.get_all()['data']:
        try:
            client.pluginParameterTypes.delete_by_id(d['id'])
        except:
            pass
    for d in client.queues.get_all()['data']:
        client.queues.delete_by_id(d['id'])

# %%
try:
    # these might fail if this has been run before
    client.users.create('testuser','testuser@gmail.com','testuserpassword','testuserpassword')
except:
    pass
try:
    client.users.create('testuser2','testuser2@gmail.com','testuserpassword','testuserpassword')
except:
    pass
client.auth.login('testuser','testuserpassword')
client.users.get_all()
client.users.current()
client.users.update_password_by_id(client.users.current()['id'],'testuserpassword','newtestuserpassword','newtestuserpassword')
try:
    client.users.modify_current('testuser','newemail@email.com') # this one should fail because we are not logged in after a password change
except:
    pass
client.auth.login('testuser','newtestuserpassword')
client.users.modify_current('testuser','newemail@email.com')
client.users.modify_current_password('newtestuserpassword','newnewtestuserpassword','newnewtestuserpassword')
try: 
    client.auth.logout(True)
except:
    pass
client.auth.login('testuser','newnewtestuserpassword')
client.users.delete_current('newnewtestuserpassword')
try: 
    client.users.failed_user_post() # if we get the schema wrong, it does return JSON, raise if not 200, but send json back to logs
except:
    pass
try:
    client.users.failed_user_get() # if we get the URL wrong, it does not return JSON
except:
    pass
client.auth.login('testuser2','testuserpassword')
client.users.get_by_id(client.users.current()['id'])
# Out:
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'email': 'testuser@gmail.com', 'password': 'testuserpassword', 'confirmPassword': 'testuserpassword'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'email': 'testuser@gmail.com', 'id': 1, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.508985+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.508985+00:00', 'lastLoginOn': None, 'passwordExpiresOn': '2025-07-09T17:42:02.508985+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser2', 'email': 'testuser2@gmail.com', 'password': 'testuserpassword', 'confirmPassword': 'testuserpassword'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser2', 'email': 'testuser2@gmail.com', 'id': 2, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.540686+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.540686+00:00', 'lastLoginOn': None, 'passwordExpiresOn': '2025-07-09T17:42:02.540686+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'password': 'testuserpassword'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'status': 'Login successful'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/users?index=0&pageLength=10', 'data': [{'username': 'testuser', 'email': 'testuser@gmail.com', 'id': 1}, {'username': 'testuser2', 'email': 'testuser2@gmail.com', 'id': 2}]}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'email': 'testuser@gmail.com', 'id': 1, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.508985+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.508985+00:00', 'lastLoginOn': '2024-07-09T17:42:02.561218+00:00', 'passwordExpiresOn': '2025-07-09T17:42:02.508985+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'email': 'testuser@gmail.com', 'id': 1, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.508985+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.508985+00:00', 'lastLoginOn': '2024-07-09T17:42:02.561218+00:00', 'passwordExpiresOn': '2025-07-09T17:42:02.508985+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'oldPassword': 'testuserpassword', 'newPassword': 'newtestuserpassword', 'confirmNewPassword': 'newtestuserpassword'} method=POST url=http://localhost:5000/api/v1/users/1/password
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'status': 'Password Change Success'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'email': 'newemail@email.com'} method=PUT url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [error    ] Error code 401 returned.       data={'username': 'testuser', 'email': 'newemail@email.com'} method=PUT response={
#     "message": "The server could not verify that you are authorized to access the URL requested. You either supplied the wrong credentials (e.g. a bad password), or your browser doesn't understand how to supply the credentials required."
# }
#  url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'password': 'newtestuserpassword'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'status': 'Login successful'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'email': 'newemail@email.com'} method=PUT url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'email': 'newemail@email.com', 'id': 1, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.508985+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.646053+00:00', 'lastLoginOn': '2024-07-09T17:42:02.635952+00:00', 'passwordExpiresOn': '2025-07-09T17:42:02.607278+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'oldPassword': 'newtestuserpassword', 'newPassword': 'newnewtestuserpassword', 'confirmNewPassword': 'newnewtestuserpassword'} method=POST url=http://localhost:5000/api/v1/users/current/password
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'status': 'Password Change Success'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'everywhere': True} method=POST url=http://localhost:5000/api/v1/auth/logout
# 2024-07-09 13:42:02 [error    ] Error code 401 returned.       data={'everywhere': True} method=POST response={
#     "message": "The server could not verify that you are authorized to access the URL requested. You either supplied the wrong credentials (e.g. a bad password), or your browser doesn't understand how to supply the credentials required."
# }
#  url=http://localhost:5000/api/v1/auth/logout
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser', 'password': 'newnewtestuserpassword'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser', 'status': 'Login successful'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'password': 'newnewtestuserpassword'} method=DELETE url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'a': 'doesnotexist'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [error    ] Error code 400 returned.       data={'a': 'doesnotexist'} method=POST response={
#     "schema_errors": {
#         "a": [
#             "Unknown field."
#         ]
#     }
# }
#  url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/doesnotexist
# 2024-07-09 13:42:02 [error    ] Error code 404 returned.       data=None method=GET response=<!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>
#  url=http://localhost:5000/api/v1/users/doesnotexist
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'testuser2', 'password': 'testuserpassword'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser2', 'status': 'Login successful'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/current
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser2', 'email': 'testuser2@gmail.com', 'id': 2, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.540686+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.540686+00:00', 'lastLoginOn': '2024-07-09T17:42:02.738776+00:00', 'passwordExpiresOn': '2025-07-09T17:42:02.540686+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/users/2
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'testuser2', 'email': 'testuser2@gmail.com', 'id': 2}
# {'username': 'testuser2', 'email': 'testuser2@gmail.com', 'id': 2}

# %%
try:
    client.users.create('queuemgr','queuemgr@dioptra.nccoe.nist.gov','lmnopQUEUErs','lmnopQUEUErs')
except:
    pass # ignore if user exists already
client.auth.login('queuemgr','lmnopQUEUErs')
cpu_id = client.queues.create(1, 'tensorflow_cpu2', 'for running tensorflow on a cpu')['id']
client.queues.modify_by_id(cpu_id, 'tensorflow_cpu2', 'for running tensorflow on a cpu - modified')
client.queues.get_all()
gpu_draft_id = client.queues.create_draft(1, 'tensorflow_gpu', 'for running tensorflow on a gpu')['id']
client.queues.modify_draft_by_draft_id(gpu_draft_id, 'tensorflow_gpu', 'for running tensorflow on a gpu - modified')
client.queues.get_drafts()
client.queues.get_draft_by_draft_id(gpu_draft_id)
client.queues.delete_draft_by_draft_id(gpu_draft_id)
client.queues.create_draft_by_queue_id(cpu_id, 'tensorflow_cpu2', 'oops my draft deleted the description')
client.queues.get_draft_by_queue_id(cpu_id)
client.queues.modify_draft_by_queue_id(cpu_id, 'tensorflow_cpu2', 'wait go back')
client.queues.delete_draft_by_queue_id(cpu_id)
client.queues.delete_by_id(cpu_id)
# Out:
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'queuemgr', 'email': 'queuemgr@dioptra.nccoe.nist.gov', 'password': 'lmnopQUEUErs', 'confirmPassword': 'lmnopQUEUErs'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'queuemgr', 'email': 'queuemgr@dioptra.nccoe.nist.gov', 'id': 3, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:02.778528+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.778528+00:00', 'lastLoginOn': None, 'passwordExpiresOn': '2025-07-09T17:42:02.778528+00:00'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'username': 'queuemgr', 'password': 'lmnopQUEUErs'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'username': 'queuemgr', 'status': 'Login successful'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'group': 1, 'name': 'tensorflow_cpu2', 'description': 'for running tensorflow on a cpu'} method=POST url=http://localhost:5000/api/v1/queues/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 7, 'snapshot': 7, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:02.819981+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.819981+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'tensorflow_cpu2', 'description': 'for running tensorflow on a cpu'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'name': 'tensorflow_cpu2', 'description': 'for running tensorflow on a cpu - modified'} method=PUT url=http://localhost:5000/api/v1/queues/7
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 7, 'snapshot': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:02.848489+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.848489+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'tensorflow_cpu2', 'description': 'for running tensorflow on a cpu - modified'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/queues?index=0&pageLength=10', 'data': [{'id': 7, 'snapshot': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:02.848489+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.848489+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'tensorflow_cpu2', 'description': 'for running tensorflow on a cpu - modified'}]}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'group': 1, 'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu'} method=POST url=http://localhost:5000/api/v1/queues/drafts
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu'}, 'createdOn': '2024-07-09T17:42:02.881000+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.881000+00:00', 'resourceType': 'queue', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu - modified'} method=PUT url=http://localhost:5000/api/v1/queues/drafts/1
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu - modified'}, 'createdOn': '2024-07-09T17:42:02.881000+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.900796+00:00', 'resourceType': 'queue', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/drafts
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/queues/drafts?index=0&pageLength=10&draft_type=all', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu - modified'}, 'createdOn': '2024-07-09T17:42:02.881000+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.900796+00:00', 'resourceType': 'queue', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}]}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/drafts/1
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_gpu', 'description': 'for running tensorflow on a gpu - modified'}, 'createdOn': '2024-07-09T17:42:02.881000+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.900796+00:00', 'resourceType': 'queue', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/queues/drafts/1
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'name': 'tensorflow_cpu2', 'description': 'oops my draft deleted the description'} method=POST url=http://localhost:5000/api/v1/queues/7/draft
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_cpu2', 'description': 'oops my draft deleted the description'}, 'createdOn': '2024-07-09T17:42:02.972218+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.972218+00:00', 'resourceType': 'queue', 'resource': 7, 'resourceSnapshot': 8, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/7/draft
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_cpu2', 'description': 'oops my draft deleted the description'}, 'createdOn': '2024-07-09T17:42:02.972218+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.972218+00:00', 'resourceType': 'queue', 'resource': 7, 'resourceSnapshot': 8, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data={'name': 'tensorflow_cpu2', 'description': 'wait go back'} method=PUT url=http://localhost:5000/api/v1/queues/7/draft
# 2024-07-09 13:42:02 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'payload': {'name': 'tensorflow_cpu2', 'description': 'wait go back'}, 'createdOn': '2024-07-09T17:42:02.972218+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.989410+00:00', 'resourceType': 'queue', 'resource': 7, 'resourceSnapshot': 8, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:02 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/queues/7/draft
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/queues/7
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'status': 'Success'}
# {'status': 'Success'}

# %%
client.tags.get_all()
client.tags.create('tag_name', 1)
client.tags.get_all()
client.tags.get_by_id(1)
client.tags.modify_by_id(1, 'new_name')
client.tags.get_resources_by_id(1)
client.tags.delete_by_id(1)
client.tags.get_all()
# Out:
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data={'name': 'tag_name', 'group': 1} method=POST url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:03.042227+00:00', 'lastModifiedOn': '2024-07-09T17:42:03.042227+00:00', 'name': 'tag_name'}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:03.042227+00:00', 'lastModifiedOn': '2024-07-09T17:42:03.042227+00:00', 'name': 'tag_name'}]}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/1
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:03.042227+00:00', 'lastModifiedOn': '2024-07-09T17:42:03.042227+00:00', 'name': 'tag_name'}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data={'name': 'new_name'} method=PUT url=http://localhost:5000/api/v1/tags/1
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 3, 'username': 'queuemgr', 'url': '/api/v1/users/3'}, 'createdOn': '2024-07-09T17:42:03.042227+00:00', 'lastModifiedOn': '2024-07-09T17:42:03.069763+00:00', 'name': 'new_name'}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/1/resources
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/tags/1/resources?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/tags/1
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': []}
# {'index': 0,
#  'isComplete': True,
#  'totalNumResults': 0,
#  'first': '/api/v1/tags?index=0&pageLength=10',
#  'data': []}

# %%
delete_all()
# Out:
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/experiments?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/entrypoints?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/jobs?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/plugins?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 6, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}]}
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 13:42:03 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 13:42:03 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/
# 2024-07-09 13:42:03 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/queues?index=0&pageLength=10', 'data': []}

# %%
def this_is_my_plugin_task(x, y):
    return y, x

try:
    client.users.create('pluginuser','pluginuser@dioptra.nccoe.nist.gov','pleasemakesuretoPLUGINthecomputer','pleasemakesuretoPLUGINthecomputer')
except:
    pass # ignore if user exists already
client.auth.login('pluginuser','pleasemakesuretoPLUGINthecomputer')

# first let's create a PluginTask for our plugin
my_plugin = PluginTask(name='this_is_my_plugin_task', inputs=[('x', 'int'), ('y', 'str')], outputs=[('y', 'str'), ('x', 'int')], client=client)
#my_plugin = PluginTask(name='this_is_my_plugin_task', inputs=[('x', 'int')], outputs=[('y', 'str')], client=client)
plugin_id = client.plugins.create(1,'first_plugin', 'this plugin does nothing')['id']
client.plugins.get_all()
client.plugins.get_by_id(plugin_id)
client.plugins.modify_by_id(plugin_id, 'first_plugin', 'this plugin still does nothing')
draft_id = client.plugins.create_draft(1,'draft_second_plugin', 'this plugin might do something someday')['id']
client.plugins.get_all_drafts()
client.plugins.get_draft_by_draft_id(draft_id)
client.plugins.modify_draft_by_draft_id(draft_id, 'draft_second_plugin', 'nevermind its hopeless')
client.plugins.delete_draft_by_draft_id(draft_id)
client.plugins.create_draft_by_plugin_id(plugin_id, 'first_plugin', 'this plugin could do something now!!')
client.plugins.modify_draft_by_plugin_id(plugin_id, 'first_plugin', 'this plugin could actually do something now!!')
client.plugins.get_draft_by_plugin_id(plugin_id)
client.plugins.delete_draft_by_plugin_id(plugin_id)

client.plugins.create_files_by_plugin_id(plugin_id, 'the_current_file.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)
client.plugins.get_files_by_plugin_id(plugin_id)
client.plugins.delete_files_by_plugin_id(plugin_id)

client.plugins.create_files_drafts_by_plugin_id(plugin_id, 'the_current_draft_file.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)
fdrafts_id = client.plugins.get_files_drafts_by_plugin_id(plugin_id)['data'][0]['id']
client.plugins.modify_files_drafts_by_plugin_id_draft_id(plugin_id, fdrafts_id, 'the_current_draft_file.py', "def this_is_my_updated_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)
client.plugins.get_files_drafts_by_plugin_id_draft_id(plugin_id, fdrafts_id)
client.plugins.delete_files_drafts_by_plugin_id_draft_id(plugin_id, fdrafts_id)

files_id = client.plugins.create_files_by_plugin_id(plugin_id, 'the_new_current_file.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)['id']
client.plugins.modify_files_by_plugin_id_file_id(plugin_id, files_id, 'the_new_current_file.py', "def this_is_my_plugin_task(x, y):\n    return y, x", "i forgot a comma", my_plugin)
client.plugins.get_files_by_plugin_id_file_id(plugin_id, files_id)
client.plugins.delete_files_by_plugin_id_file_id(plugin_id, files_id)


file_id = client.plugins.create_files_by_plugin_id(plugin_id, 'NEW_FILE.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)['id']
client.plugins.create_files_draft_by_plugin_id_file_id(plugin_id, file_id, 'newfile.py', 'def invalid_python(x,y):', 'this is a test of the emergency plugin system', my_plugin)
client.plugins.modify_files_draft_by_plugin_id_file_id(plugin_id, file_id, 'newfile.py', 'def invalider_python(x,y):', 'test successful', my_plugin)
client.plugins.get_files_draft_by_plugin_id_file_id(plugin_id, file_id)
client.plugins.get_snapshots_by_plugin_id_file_id(plugin_id, file_id)
# cannot test below. do not know how to make a snapshot
# client.plugins.get_snapshots_by_plugin_id_file_id_snapshot_id(plugin_id, file_id, snapshot_id)
# client.plugin.get_snapshots_by_plugin_id(plugin_id)
# client.plugin.get_snapshot_by_plugin_id_snapshot_id(plugin_id, snapshot_id) # no way to create snapshots as of now?
tag_id = client.tags.create('youreit', 1)['id']
tag_id2 = client.tags.create('nuhuh', 1)['id']
client.plugins.add_tags_by_plugin_id(plugin_id, [tag_id])
client.plugins.modify_tags_by_plugin_id(plugin_id, [tag_id, tag_id2])
client.plugins.get_tags_by_plugin_id(plugin_id)
client.plugins.delete_tags_by_plugin_id_tag_id(plugin_id, tag_id)
client.plugins.delete_tags_by_plugin_id(plugin_id)
client.plugins.delete_by_id(plugin_id)

client.plugins.add_tags_by_plugin_id_file_id(plugin_id, file_id, [tag_id])
client.plugins.modify_tags_by_plugin_id_file_id(plugin_id, file_id, [tag_id, tag_id2])
client.plugins.get_tags_by_plugin_id_file_id(plugin_id, file_id)
client.plugins.delete_tags_by_plugin_id_file_id(plugin_id, file_id)
client.plugins.add_tags_by_plugin_id_file_id(plugin_id, file_id, [tag_id])
client.plugins.delete_tags_by_plugin_id_file_id_tag_id(plugin_id, file_id, tag_id)
client.plugins.delete_files_draft_by_plugin_id_file_id(plugin_id, file_id)

client.pluginParameterTypes.get_all()
type_id = client.pluginParameterTypes.create(1, 'bool', 'its a yes or no question', {})['id']
client.pluginParameterTypes.modify_by_id(type_id, 'bool', 'it cant be None. probably', {})
client.pluginParameterTypes.get_by_id(type_id)
client.pluginParameterTypes.delete_by_id(type_id)
# Out:
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'username': 'pluginuser', 'email': 'pluginuser@dioptra.nccoe.nist.gov', 'password': 'pleasemakesuretoPLUGINthecomputer', 'confirmPassword': 'pleasemakesuretoPLUGINthecomputer'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'username': 'pluginuser', 'email': 'pluginuser@dioptra.nccoe.nist.gov', 'id': 4, 'groups': [{'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}], 'createdOn': '2024-07-09T17:42:04.326560+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.326560+00:00', 'lastLoginOn': None, 'passwordExpiresOn': '2025-07-09T17:42:04.326560+00:00'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'username': 'pluginuser', 'password': 'pleasemakesuretoPLUGINthecomputer'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'username': 'pluginuser', 'status': 'Login successful'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'group': 1, 'name': 'first_plugin', 'description': 'this plugin does nothing'} method=POST url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 8, 'snapshot': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.365177+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.365177+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'first_plugin', 'description': 'this plugin does nothing', 'files': []}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/plugins?index=0&pageLength=10', 'data': [{'id': 8, 'snapshot': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.365177+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.365177+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'first_plugin', 'description': 'this plugin does nothing', 'files': []}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 8, 'snapshot': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.365177+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.365177+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'first_plugin', 'description': 'this plugin does nothing', 'files': []}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'name': 'first_plugin', 'description': 'this plugin still does nothing'} method=PUT url=http://localhost:5000/api/v1/plugins/8
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 8, 'snapshot': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.461652+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.461652+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'first_plugin', 'description': 'this plugin still does nothing', 'files': []}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'group': 1, 'name': 'draft_second_plugin', 'description': 'this plugin might do something someday'} method=POST url=http://localhost:5000/api/v1/plugins/drafts
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'draft_second_plugin', 'description': 'this plugin might do something someday'}, 'createdOn': '2024-07-09T17:42:04.477227+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.477227+00:00', 'resourceType': 'plugin', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/drafts
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/plugins/drafts?index=0&pageLength=10&draft_type=all', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'draft_second_plugin', 'description': 'this plugin might do something someday'}, 'createdOn': '2024-07-09T17:42:04.477227+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.477227+00:00', 'resourceType': 'plugin', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'draft_second_plugin', 'description': 'this plugin might do something someday'}, 'createdOn': '2024-07-09T17:42:04.477227+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.477227+00:00', 'resourceType': 'plugin', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'name': 'draft_second_plugin', 'description': 'nevermind its hopeless'} method=PUT url=http://localhost:5000/api/v1/plugins/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'draft_second_plugin', 'description': 'nevermind its hopeless'}, 'createdOn': '2024-07-09T17:42:04.477227+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.504132+00:00', 'resourceType': 'plugin', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'name': 'first_plugin', 'description': 'this plugin could do something now!!'} method=POST url=http://localhost:5000/api/v1/plugins/8/draft
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'first_plugin', 'description': 'this plugin could do something now!!'}, 'createdOn': '2024-07-09T17:42:04.524506+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.524506+00:00', 'resourceType': 'plugin', 'resource': 8, 'resourceSnapshot': 10, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'name': 'first_plugin', 'description': 'this plugin could actually do something now!!'} method=PUT url=http://localhost:5000/api/v1/plugins/8/draft
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'first_plugin', 'description': 'this plugin could actually do something now!!'}, 'createdOn': '2024-07-09T17:42:04.524506+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.536105+00:00', 'resourceType': 'plugin', 'resource': 8, 'resourceSnapshot': 10, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/draft
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'name': 'first_plugin', 'description': 'this plugin could actually do something now!!'}, 'createdOn': '2024-07-09T17:42:04.524506+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.536105+00:00', 'resourceType': 'plugin', 'resource': 8, 'resourceSnapshot': 10, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/draft
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 6, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'group': 1, 'name': 'str', 'description': 'str plugin parameter', 'structure': {}} method=POST url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'group': 1, 'name': 'int', 'description': 'int plugin parameter', 'structure': {}} method=POST url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'the_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/8/files
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 11, 'snapshot': 13, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.641981+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.641981+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/plugins/8/files?index=0&pageLength=10', 'data': [{'id': 11, 'snapshot': 13, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.641981+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.641981+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': [11], 'status': 'Success'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/8/files/drafts
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': "i hope i didn't forget a comma"}, 'createdOn': '2024-07-09T17:42:04.757496+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.757496+00:00', 'resourceType': 'plugin_file', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/drafts
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/plugins/8/files/drafts?index=0&pageLength=10&draft_type=all', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': "i hope i didn't forget a comma"}, 'createdOn': '2024-07-09T17:42:04.757496+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.757496+00:00', 'resourceType': 'plugin_file', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_updated_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=PUT url=http://localhost:5000/api/v1/plugins/8/files/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_updated_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': "i hope i didn't forget a comma"}, 'createdOn': '2024-07-09T17:42:04.757496+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.790824+00:00', 'resourceType': 'plugin_file', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'the_current_draft_file.py', 'contents': 'def this_is_my_updated_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': "i hope i didn't forget a comma"}, 'createdOn': '2024-07-09T17:42:04.757496+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.790824+00:00', 'resourceType': 'plugin_file', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files/drafts/1
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/8/files
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 12, 'snapshot': 14, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.830884+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.830884+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y, x', 'description': 'i forgot a comma', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=PUT url=http://localhost:5000/api/v1/plugins/8/files/12
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 12, 'snapshot': 15, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.882934+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.882934+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y, x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': 'i forgot a comma', 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/12
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 12, 'snapshot': 15, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.882934+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.882934+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y, x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': 'i forgot a comma', 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files/12
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': [12], 'status': 'Success'}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'NEW_FILE.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/8/files
# 2024-07-09 13:42:04 [debug    ] Response received.             json={'id': 13, 'snapshot': 16, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.958627+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.958627+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'NEW_FILE.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 8, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/8', 'name': 'first_plugin'}}
# 2024-07-09 13:42:04 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# ...
# 2024-07-09 13:42:04 [debug    ] Request made.                  data={'filename': 'newfile.py', 'contents': 'def invalider_python(x,y):', 'description': 'test successful', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': '10'}, {'name': 'y', 'parameterType': '9'}], 'outputParams': [{'name': 'y', 'parameterType': '9'}, {'name': 'x', 'parameterType': '10'}]}]} method=PUT url=http://localhost:5000/api/v1/plugins/8/files/13/draft
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'newfile.py', 'contents': 'def invalider_python(x,y):', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': 'test successful'}, 'createdOn': '2024-07-09T17:42:04.984164+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.002400+00:00', 'resourceType': 'plugin_file', 'resource': 13, 'resourceSnapshot': 16, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/13/draft
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'payload': {'filename': 'newfile.py', 'contents': 'def invalider_python(x,y):', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'required': True}, {'name': 'y', 'required': True}], 'outputParams': [{'name': 'y'}, {'name': 'x'}]}], 'description': 'test successful'}, 'createdOn': '2024-07-09T17:42:04.984164+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.002400+00:00', 'resourceType': 'plugin_file', 'resource': 13, 'resourceSnapshot': 16, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/13/snapshots
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/plugins/8/files/13/snapshots?index=0&pageLength=10', 'data': [{'id': 13, 'snapshot': 16, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.958627+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.958627+00:00', 'latestSnapshot': True, 'tags': [], 'filename': 'NEW_FILE.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin_task', 'inputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 10, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/10', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 9, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/9', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma"}]}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'name': 'youreit', 'group': 1} method=POST url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.051346+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.051346+00:00', 'name': 'youreit'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'name': 'nuhuh', 'group': 1} method=POST url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.063175+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.063175+00:00', 'name': 'nuhuh'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/plugins/8/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'ids': [1, 2]} method=PUT url=http://localhost:5000/api/v1/plugins/8/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/tags/1
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [2], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [8], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/plugins/8/files/13/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'ids': [1, 2]} method=PUT url=http://localhost:5000/api/v1/plugins/8/files/13/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/8/files/13/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files/13/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [1, 2], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/plugins/8/files/13/tags
# 2024-07-09 13:42:05 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files/13/tags/1
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/8/files/13/draft
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'group': 1, 'name': 'bool', 'description': 'its a yes or no question', 'structure': {}} method=POST url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 14, 'snapshot': 17, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.227576+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.227576+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'bool', 'description': 'its a yes or no question', 'structure': {}}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data={'name': 'bool', 'description': 'it cant be None. probably', 'structure': {}} method=PUT url=http://localhost:5000/api/v1/pluginParameterTypes/14
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 14, 'snapshot': 18, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.267199+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.267199+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'bool', 'description': 'it cant be None. probably', 'structure': {}}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/14
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': 14, 'snapshot': 18, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.267199+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.267199+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'bool', 'description': 'it cant be None. probably', 'structure': {}}
# 2024-07-09 13:42:05 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/14
# 2024-07-09 13:42:05 [debug    ] Response received.             json={'id': [14], 'status': 'Success'}
# {'id': [14], 'status': 'Success'}

# %%
delete_all()
# Out:
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/experiments?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/entrypoints?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/jobs?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/plugins?index=0&pageLength=10', 'data': []}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.051346+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.051346+00:00', 'name': 'youreit'}, {'id': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:05.063175+00:00', 'lastModifiedOn': '2024-07-09T17:42:05.063175+00:00', 'name': 'nuhuh'}]}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/tags/1
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/tags/2
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'id': [2], 'status': 'Success'}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 9, 'snapshot': 11, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.582748+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.582748+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 10, 'snapshot': 12, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 4, 'username': 'pluginuser', 'url': '/api/v1/users/4'}, 'createdOn': '2024-07-09T17:42:04.602279+00:00', 'lastModifiedOn': '2024-07-09T17:42:04.602279+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 13:42:07 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/9
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'id': [9], 'status': 'Success'}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/10
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'id': [10], 'status': 'Success'}
# 2024-07-09 13:42:07 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/
# 2024-07-09 13:42:07 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/queues?index=0&pageLength=10', 'data': []}

# %%
try:
    client.users.create('finalman','finalman@dioptra.nccoe.nist.gov','fighteroftheDRAFTman','fighteroftheDRAFTman')
except:
    pass # ignore if user exists already
client.auth.login('finalman','fighteroftheDRAFTman')
exp_id = client.experiments.create(1, 'dioptra v1s first experiment', 'get the camera', [])['id']
client.experiments.get_all()
client.experiments.create_draft(1, 'dioptra v1s first DRAFT experiment', 'dont need the camera for this', [])
draft_id = client.experiments.get_drafts()['data'][0]['id']
client.experiments.get_drafts_by_draft_id(draft_id)
client.experiments.modify_drafts_by_draft_id(draft_id, 'dioptra v1s first DRAFT experiment', 'removed description', [])
client.experiments.delete_drafts_by_draft_id(draft_id)
client.experiments.modify_by_id(exp_id,'dioptra v1s first experiment','modded',[])
client.experiments.get_by_id(exp_id)
client.experiments.create_draft_by_experiment_id(exp_id, 'v1draft', 'drafty in here', [])
client.experiments.modify_draft_by_experiment_id(exp_id, 'editing is what drafts are for', 'drafty in here', [])
client.experiments.get_draft_by_experiment_id(exp_id)
client.experiments.delete_draft_by_experiment_id(exp_id)

tag_id = client.tags.create('youreit', 1)['id']
tag_id2 = client.tags.create('nuhuh', 1)['id']

try: 
    queue_id = client.queues.create(1, 'tensorflow_cpu3', 'for running tensorflow on a cpu')['id']
except:
    pass

my_plugin = PluginTask(name='this_is_my_plugin', inputs=[('x', 'int'), ('y', 'str')], outputs=[('y', 'str'), ('x', 'int')], client=client)
my_plugin2 = PluginTask(name='this_is_not_my_plugin', inputs=[('x', 'int'), ('y', 'str')], outputs=[('y', 'str'), ('x', 'int')], client=client)

try: 
    plugin_id = client.plugins.create(1,'not_the_first_plugin', 'this plugin does nothing')['id']
    files_id = client.plugins.create_files_by_plugin_id(plugin_id, 'the_new_current_file.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin)['id']
    client.plugins.get_files_by_plugin_id_file_id(plugin_id, files_id)

except:
    pass
try:
    plugin_id2 = client.plugins.create(1,'not_the_first_plugin2', 'this plugin does nothing')['id']
    files_id = client.plugins.create_files_by_plugin_id(plugin_id2, 'the_new_current_file.py', "def this_is_my_plugin_task(x, y):\n    return y x", "i hope i didn't forget a comma", my_plugin2)['id']
    client.plugins.get_files_by_plugin_id_file_id(plugin_id2, files_id)
except:
    pass

# entrypoints testing#
ep_id = client.entrypoints.create(1, 'entrypoint1', 'this is where you entry', 'task graph?',
                                  [{
                                      'name': 'parameter_name',
                                      'defaultValue': 'default_value',
                                      'parameterType': 'string'
                                  }], queues = [queue_id], plugins=[plugin_id])['id']
client.entrypoints.get_all()
ep_draft_id = client.entrypoints.create_draft(
    1, 'entrypoint1', 'entry draft', 'task graph?',
                                  [{
                                      'name': 'parameter_name',
                                      'defaultValue': 'default_value',
                                      'parameterType': 'string'
                                  }], queues = [queue_id], plugins=[plugin_id]
)['id']
client.entrypoints.get_drafts()
client.entrypoints.modify_draft_by_draft_id(ep_draft_id, 'new name', 'new desc', 'task graph?',
                                    [{
                                        'name': 'parameter_name',
                                        'defaultValue': 'default_value',
                                        'parameterType': 'string'
                                    }], queues = [queue_id])
client.entrypoints.get_draft_by_draft_id(ep_draft_id)
client.entrypoints.delete_draft_by_draft_id(ep_draft_id)
client.entrypoints.modify_by_id(ep_id, 'new name', 'new desc', 'task graph?',
                                    [{
                                        'name': 'parameter_name',
                                        'defaultValue': 'default_value',
                                        'parameterType': 'string'
                                    }], queues = [queue_id])  # TODO: no plugins? correct?
client.entrypoints.get_by_id(ep_id)
client.entrypoints.create_draft_by_entrypoint_id(ep_id, 'new name', 'new desc', 'task graph?',
                                    [{
                                        'name': 'parameter_name',
                                        'defaultValue': 'default_value',
                                        'parameterType': 'string'
                                    }], queues = [queue_id], plugins=[plugin_id])
client.entrypoints.modify_draft_by_entrypoint_id(ep_id, 'new new name', 'new desc', 'task graph?',
                                    [{
                                        'name': 'parameter_name',
                                        'defaultValue': 'default_value',
                                        'parameterType': 'string'
                                    }], queues = [queue_id], plugins=[plugin_id])
client.entrypoints.get_draft_by_entrypoint_id(ep_id)
client.entrypoints.delete_draft_by_entrypoint_id(ep_id)

#BROKEN???
client.plugins.get_all()
client.entrypoints.add_plugins_by_entrypoint_id(ep_id, [plugin_id2])
client.entrypoints.get_plugins_by_entrypoint_id(ep_id)
client.entrypoints.get_plugins_by_entrypoint_id_plugin_id(ep_id, plugin_id2)
client.entrypoints.delete_plugins_by_entrypoint_id_plugin_id(ep_id, plugin_id2)

client.entrypoints.add_queues_by_entrypoint_id(ep_id,[queue_id])
client.entrypoints.modify_queues_by_entrypoint_id(ep_id,[queue_id])
client.entrypoints.delete_queues_by_entrypoint_id(ep_id)
client.entrypoints.add_queues_by_entrypoint_id(ep_id,[queue_id])
client.entrypoints.delete_queues_by_entrypoint_id_queue_id(ep_id, queue_id)
snap_id = client.entrypoints.get_snapshots_by_entrypoint_id(ep_id)['data'][0]['snapshot']
client.entrypoints.get_snapshots_by_entrypoint_id_snapshot_id(ep_id, snap_id)
client.entrypoints.add_tags_by_entrypoint_id(ep_id, [tag_id])
client.entrypoints.modify_tags_by_entrypoint_id(ep_id, [tag_id, tag_id2])
client.entrypoints.get_tags_by_entrypoint_id(ep_id)
client.entrypoints.delete_tags_by_entrypoint_id(ep_id)
client.entrypoints.add_tags_by_entrypoint_id(ep_id, [tag_id])
client.entrypoints.delete_tags_by_entrypoint_id_tag_id(ep_id, tag_id)

client.experiments.add_entrypoints_by_experiment_id(exp_id, [ep_id])
client.experiments.modify_entrypoints_by_experiment_id(exp_id, [ep_id])
client.experiments.get_entrypoints_by_experiment_id(exp_id)
client.experiments.delete_entrypoints_by_experiment_id(exp_id)
client.experiments.add_entrypoints_by_experiment_id(exp_id, [ep_id])
client.entrypoints.add_queues_by_entrypoint_id(ep_id,[queue_id])

# jobs testing #
job_id = client.experiments.create_jobs_by_experiment_id(exp_id, 'job description', queue_id, ep_id, {}, '24h')['id']
job_id = client.jobs.get_all()['data'][0]['id']
snap_id = client.jobs.get_snapshots_by_job_id(job_id)['data'][0]['snapshot']
client.jobs.get_snapshots_by_job_id_snapshot_id(job_id, snap_id)
client.jobs.get_status_by_job_id(job_id)
client.jobs.add_tags_by_job_id(job_id, [tag_id])
client.jobs.modify_tags_by_job_id(job_id, [tag_id, tag_id2])
client.jobs.get_tags_by_job_id(job_id)
client.jobs.delete_tags_by_job_id(job_id)
client.jobs.add_tags_by_job_id(job_id, [tag_id])
client.jobs.delete_tags_by_job_id_tag_id(job_id, tag_id)
client.jobs.delete_by_id(job_id)
job_id = client.experiments.create_jobs_by_experiment_id(exp_id, 'job description', queue_id, ep_id, {}, '24h')['id']

# note - needs entrypoint endpoint

client.experiments.get_jobs_by_experiment_id(exp_id)
client.experiments.get_jobs_by_experiment_id_job_id(exp_id, job_id)
client.experiments.modify_jobs_status_by_experiment_id_job_id(exp_id, job_id, "started")
client.experiments.get_jobs_status_by_experiment_id_job_id(exp_id, job_id)
job_id = client.experiments.create_jobs_by_experiment_id(exp_id, 'job description', queue_id, ep_id, {}, '24h')['id']
client.experiments.delete_jobs_by_experiment_id_job_id(exp_id, job_id)
snapshot_id = client.experiments.get_snapshots_by_experiment_id(exp_id)['data'][0]['snapshot']
client.experiments.get_snapshots_by_experiment_id_snapshot_id(exp_id, snapshot_id)

client.experiments.add_tags_by_experiment_id(exp_id, [tag_id])
client.experiments.modify_tags_by_experiment_id(exp_id, [tag_id, tag_id2])
client.experiments.get_tags_by_experiment_id(exp_id)
client.experiments.delete_tags_by_experiment_id(exp_id)
client.experiments.add_tags_by_experiment_id(exp_id, [tag_id])
client.experiments.delete_tags_by_experiment_id_tag_id(exp_id, tag_id)

client.experiments.delete_entrypoints_by_experiment_id_entrypoint_id(exp_id, ep_id)

client.entrypoints.delete_by_id(ep_id)
client.experiments.delete_by_id(exp_id)
client.jobs.get_all()
# Out:
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'username': 'finalman', 'email': 'finalman@dioptra.nccoe.nist.gov', 'password': 'fighteroftheDRAFTman', 'confirmPassword': 'fighteroftheDRAFTman'} method=POST url=http://localhost:5000/api/v1/users/
# 2024-07-09 14:50:44 [error    ] Error code 400 returned.       data={'username': 'finalman', 'email': 'finalman@dioptra.nccoe.nist.gov', 'password': 'fighteroftheDRAFTman', 'confirmPassword': 'fighteroftheDRAFTman'} method=POST response={
#     "message": "Bad Request - The username on the registration form is not available. Please select another and resubmit."
# }
#  url=http://localhost:5000/api/v1/users/
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'username': 'finalman', 'password': 'fighteroftheDRAFTman'} method=POST url=http://localhost:5000/api/v1/auth/login
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'username': 'finalman', 'status': 'Login successful'}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'group': 1, 'name': 'dioptra v1s first experiment', 'description': 'get the camera', 'entrypoints': []} method=POST url=http://localhost:5000/api/v1/experiments/
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'id': 37, 'snapshot': 50, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:44.929125+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.929125+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'get the camera', 'entrypoints': [], 'jobs': []}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/experiments?index=0&pageLength=10', 'data': [{'id': 37, 'snapshot': 50, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:44.929125+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.929125+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'get the camera', 'entrypoints': [], 'jobs': []}]}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'group': 1, 'name': 'dioptra v1s first DRAFT experiment', 'description': 'dont need the camera for this', 'entrypoints': []} method=POST url=http://localhost:5000/api/v1/experiments/drafts
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'dioptra v1s first DRAFT experiment', 'description': 'dont need the camera for this', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:44.953059+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.953059+00:00', 'resourceType': 'experiment', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/drafts
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/experiments/drafts?index=0&pageLength=10&draft_type=all', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'dioptra v1s first DRAFT experiment', 'description': 'dont need the camera for this', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:44.953059+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.953059+00:00', 'resourceType': 'experiment', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}]}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/drafts/1
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'dioptra v1s first DRAFT experiment', 'description': 'dont need the camera for this', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:44.953059+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.953059+00:00', 'resourceType': 'experiment', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'name': 'dioptra v1s first DRAFT experiment', 'description': 'removed description', 'entrypoints': []} method=PUT url=http://localhost:5000/api/v1/experiments/drafts/1
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'dioptra v1s first DRAFT experiment', 'description': 'removed description', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:44.953059+00:00', 'lastModifiedOn': '2024-07-09T18:50:44.980595+00:00', 'resourceType': 'experiment', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/drafts/1
# 2024-07-09 14:50:44 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:44 [debug    ] Request made.                  data={'name': 'dioptra v1s first experiment', 'description': 'modded', 'entrypoints': []} method=PUT url=http://localhost:5000/api/v1/experiments/37
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 37, 'snapshot': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.004989+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.004989+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'modded', 'entrypoints': [], 'jobs': []}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 37, 'snapshot': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.004989+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.004989+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'modded', 'entrypoints': [], 'jobs': []}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'v1draft', 'description': 'drafty in here', 'entrypoints': []} method=POST url=http://localhost:5000/api/v1/experiments/37/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'v1draft', 'description': 'drafty in here', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:45.028271+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.028271+00:00', 'resourceType': 'experiment', 'resource': 37, 'resourceSnapshot': 51, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'editing is what drafts are for', 'description': 'drafty in here', 'entrypoints': []} method=PUT url=http://localhost:5000/api/v1/experiments/37/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'editing is what drafts are for', 'description': 'drafty in here', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:45.028271+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.037978+00:00', 'resourceType': 'experiment', 'resource': 37, 'resourceSnapshot': 51, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'editing is what drafts are for', 'description': 'drafty in here', 'entrypoints': []}, 'createdOn': '2024-07-09T18:50:45.028271+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.037978+00:00', 'resourceType': 'experiment', 'resource': 37, 'resourceSnapshot': 51, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'youreit', 'group': 1} method=POST url=http://localhost:5000/api/v1/tags/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.068746+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.068746+00:00', 'name': 'youreit'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'nuhuh', 'group': 1} method=POST url=http://localhost:5000/api/v1/tags/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.082920+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.082920+00:00', 'name': 'nuhuh'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'tensorflow_cpu3', 'description': 'for running tensorflow on a cpu'} method=POST url=http://localhost:5000/api/v1/queues/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 38, 'snapshot': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.094641+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.094641+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'tensorflow_cpu3', 'description': 'for running tensorflow on a cpu'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'not_the_first_plugin', 'description': 'this plugin does nothing'} method=POST url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 39, 'snapshot': 53, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.106425+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.106425+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin', 'description': 'this plugin does nothing', 'files': []}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 6, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'str', 'description': 'str plugin parameter', 'structure': {}} method=POST url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 40, 'snapshot': 54, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.130307+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.130307+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'int', 'description': 'int plugin parameter', 'structure': {}} method=POST url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 41, 'snapshot': 55, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.142769+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.142769+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': '41'}, {'name': 'y', 'parameterType': '40'}], 'outputParams': [{'name': 'y', 'parameterType': '40'}, {'name': 'x', 'parameterType': '41'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/39/files
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 42, 'snapshot': 56, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.160077+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.160077+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 39, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/39', 'name': 'not_the_first_plugin'}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/39/files/42
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 42, 'snapshot': 56, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.160077+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.160077+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 39, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/39', 'name': 'not_the_first_plugin'}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'not_the_first_plugin2', 'description': 'this plugin does nothing'} method=POST url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 43, 'snapshot': 57, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.185784+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.185784+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin2', 'description': 'this plugin does nothing', 'files': []}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 40, 'snapshot': 54, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.130307+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.130307+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 41, 'snapshot': 55, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.142769+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.142769+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'description': "i hope i didn't forget a comma", 'tasks': [{'name': 'this_is_not_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': '41'}, {'name': 'y', 'parameterType': '40'}], 'outputParams': [{'name': 'y', 'parameterType': '40'}, {'name': 'x', 'parameterType': '41'}]}]} method=POST url=http://localhost:5000/api/v1/plugins/43/files
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 44, 'snapshot': 58, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.209997+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.209997+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_not_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 43, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/43', 'name': 'not_the_first_plugin2'}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/43/files/44
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 44, 'snapshot': 58, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.209997+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.209997+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'filename': 'the_new_current_file.py', 'contents': 'def this_is_my_plugin_task(x, y):\n    return y x', 'tasks': [{'name': 'this_is_not_my_plugin', 'inputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}, 'required': True}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}, 'required': True}], 'outputParams': [{'name': 'x', 'parameterType': {'id': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/41', 'name': 'int'}}, {'name': 'y', 'parameterType': {'id': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/pluginParameterTypes/40', 'name': 'str'}}]}], 'description': "i hope i didn't forget a comma", 'plugin': {'id': 43, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/43', 'name': 'not_the_first_plugin2'}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'entrypoint1', 'description': 'this is where you entry', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]} method=POST url=http://localhost:5000/api/v1/entrypoints/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 45, 'snapshot': 59, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.240451+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.240451+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'entrypoint1', 'description': 'this is where you entry', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}], 'queues': [{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/entrypoints?index=0&pageLength=10', 'data': [{'id': 45, 'snapshot': 59, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.240451+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.240451+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'entrypoint1', 'description': 'this is where you entry', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}], 'queues': [{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'group': 1, 'name': 'entrypoint1', 'description': 'entry draft', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]} method=POST url=http://localhost:5000/api/v1/entrypoints/drafts
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'entrypoint1', 'description': 'entry draft', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]}, 'createdOn': '2024-07-09T18:50:45.269310+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.269310+00:00', 'resourceType': 'entry_point', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/drafts
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/entrypoints/drafts?index=0&pageLength=10&draft_type=all', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'entrypoint1', 'description': 'entry draft', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]}, 'createdOn': '2024-07-09T18:50:45.269310+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.269310+00:00', 'resourceType': 'entry_point', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38]} method=PUT url=http://localhost:5000/api/v1/entrypoints/drafts/1
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38]}, 'createdOn': '2024-07-09T18:50:45.269310+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.290433+00:00', 'resourceType': 'entry_point', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/drafts/1
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38]}, 'createdOn': '2024-07-09T18:50:45.269310+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.290433+00:00', 'resourceType': 'entry_point', 'resource': None, 'resourceSnapshot': None, 'metadata': {}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/drafts/1
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38]} method=PUT url=http://localhost:5000/api/v1/entrypoints/45
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 45, 'snapshot': 60, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.318178+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.318178+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}], 'queues': [{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 45, 'snapshot': 60, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.318178+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.318178+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}], 'queues': [{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]} method=POST url=http://localhost:5000/api/v1/entrypoints/45/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]}, 'createdOn': '2024-07-09T18:50:45.346757+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.346757+00:00', 'resourceType': 'entry_point', 'resource': 45, 'resourceSnapshot': 60, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'name': 'new new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]} method=PUT url=http://localhost:5000/api/v1/entrypoints/45/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'new new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]}, 'createdOn': '2024-07-09T18:50:45.346757+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.359482+00:00', 'resourceType': 'entry_point', 'resource': 45, 'resourceSnapshot': 60, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'payload': {'name': 'new new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'queues': [38], 'plugins': [39]}, 'createdOn': '2024-07-09T18:50:45.346757+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.359482+00:00', 'resourceType': 'entry_point', 'resource': 45, 'resourceSnapshot': 60, 'metadata': {'num_other_drafts': 0}}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/45/draft
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/plugins?index=0&pageLength=10', 'data': [{'id': 39, 'snapshot': 53, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.106425+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.106425+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin', 'description': 'this plugin does nothing', 'files': [{'id': 42, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/39/files/42', 'filename': 'the_new_current_file.py'}]}, {'id': 43, 'snapshot': 57, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.185784+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.185784+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin2', 'description': 'this plugin does nothing', 'files': [{'id': 44, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/43/files/44', 'filename': 'the_new_current_file.py'}]}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'plugins': [43]} method=POST url=http://localhost:5000/api/v1/entrypoints/45/plugins
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}, {'id': 43, 'name': 'not_the_first_plugin2', 'snapshotId': 57, 'url': '/api/v1/plugins/43/snapshots/57', 'files': [{'id': 44, 'filename': 'the_new_current_file.py', 'snapshotId': 58, 'url': '/api/v1/plugins/43/files/44/snapshots/58'}]}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45/plugins
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}, {'id': 43, 'name': 'not_the_first_plugin2', 'snapshotId': 57, 'url': '/api/v1/plugins/43/snapshots/57', 'files': [{'id': 44, 'filename': 'the_new_current_file.py', 'snapshotId': 58, 'url': '/api/v1/plugins/43/files/44/snapshots/58'}]}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45/plugins/43
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 43, 'name': 'not_the_first_plugin2', 'snapshotId': 57, 'url': '/api/v1/plugins/43/snapshots/57', 'files': [{'id': 44, 'filename': 'the_new_current_file.py', 'snapshotId': 58, 'url': '/api/v1/plugins/43/files/44/snapshots/58'}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/45/plugins/43
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [43], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [38]} method=POST url=http://localhost:5000/api/v1/entrypoints/45/queues
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [38]} method=PUT url=http://localhost:5000/api/v1/entrypoints/45/queues
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/45/queues
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [38], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [38]} method=POST url=http://localhost:5000/api/v1/entrypoints/45/queues
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 38, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38', 'name': 'tensorflow_cpu3'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/45/queues/38
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [38], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45/snapshots
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 4, 'first': '/api/v1/entrypoints/45/snapshots?index=0&pageLength=10', 'data': [{'id': 45, 'snapshot': 59, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.240451+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.506437+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'entrypoint1', 'description': 'this is where you entry', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}]}, {'id': 45, 'snapshot': 60, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.318178+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.506437+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': []}, {'id': 45, 'snapshot': 61, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.398428+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.506437+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [], 'plugins': [{'id': 43, 'name': 'not_the_first_plugin2', 'snapshotId': 57, 'url': '/api/v1/plugins/43/snapshots/57', 'files': [{'id': 44, 'filename': 'the_new_current_file.py', 'snapshotId': 58, 'url': '/api/v1/plugins/43/files/44/snapshots/58'}]}]}, {'id': 45, 'snapshot': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.506437+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.506437+00:00', 'latestSnapshot': True, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}]}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/45/snapshots/59
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 45, 'snapshot': 59, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.240451+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.506437+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'entrypoint1', 'description': 'this is where you entry', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 39, 'name': 'not_the_first_plugin', 'snapshotId': 53, 'url': '/api/v1/plugins/39/snapshots/53', 'files': [{'id': 42, 'filename': 'the_new_current_file.py', 'snapshotId': 56, 'url': '/api/v1/plugins/39/files/42/snapshots/56'}]}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/entrypoints/45/tags
# ...
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/46/status
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 46, 'status': 'queued'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/jobs/46/tags
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [1, 2]} method=PUT url=http://localhost:5000/api/v1/jobs/46/tags
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/46/tags
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/jobs/46/tags
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [1, 2], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/jobs/46/tags
# 2024-07-09 14:50:45 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/jobs/46/tags/1
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/jobs/46
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': [46], 'status': 'Success'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'description': 'job description', 'queue': 38, 'entrypoint': 45, 'values': {}, 'timeout': '24h'} method=POST url=http://localhost:5000/api/v1/experiments/37/jobs
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 47, 'snapshot': 64, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.939399+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.939399+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'description': 'job description', 'queue': {'snapshotId': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38/snapshots/52', 'name': 'tensorflow_cpu3'}, 'experiment': {'snapshotId': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/experiments/37/snapshots/51', 'name': 'dioptra v1s first experiment'}, 'entrypoint': {'snapshotId': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/entrypoints/45/snapshots/62', 'name': 'new name'}, 'values': {'parameter_name': 'default_value'}, 'timeout': '24h', 'status': 'queued'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/jobs
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/experiments/37/jobs?index=0&pageLength=10', 'data': [{'id': 47, 'snapshot': 64, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.939399+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.939399+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'description': 'job description', 'queue': {'snapshotId': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38/snapshots/52', 'name': 'tensorflow_cpu3'}, 'experiment': {'snapshotId': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/experiments/37/snapshots/51', 'name': 'dioptra v1s first experiment'}, 'entrypoint': {'snapshotId': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/entrypoints/45/snapshots/62', 'name': 'new name'}, 'values': {'parameter_name': 'default_value'}, 'timeout': '24h', 'status': 'queued'}]}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/jobs/47
# 2024-07-09 14:50:45 [debug    ] Response received.             json={'id': 47, 'snapshot': 64, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.939399+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.939399+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'description': 'job description', 'queue': {'snapshotId': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38/snapshots/52', 'name': 'tensorflow_cpu3'}, 'experiment': {'snapshotId': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/experiments/37/snapshots/51', 'name': 'dioptra v1s first experiment'}, 'entrypoint': {'snapshotId': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/entrypoints/45/snapshots/62', 'name': 'new name'}, 'values': {'parameter_name': 'default_value'}, 'timeout': '24h', 'status': 'queued'}
# 2024-07-09 14:50:45 [debug    ] Request made.                  data={'status': 'started'} method=PUT url=http://localhost:5000/api/v1/experiments/37/jobs/47/status
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': 47, 'status': 'started'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/jobs/47/status
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': 47, 'status': 'started'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data={'description': 'job description', 'queue': 38, 'entrypoint': 45, 'values': {}, 'timeout': '24h'} method=POST url=http://localhost:5000/api/v1/experiments/37/jobs
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': 48, 'snapshot': 66, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:46.030688+00:00', 'lastModifiedOn': '2024-07-09T18:50:46.030688+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'description': 'job description', 'queue': {'snapshotId': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38/snapshots/52', 'name': 'tensorflow_cpu3'}, 'experiment': {'snapshotId': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/experiments/37/snapshots/51', 'name': 'dioptra v1s first experiment'}, 'entrypoint': {'snapshotId': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/entrypoints/45/snapshots/62', 'name': 'new name'}, 'values': {'parameter_name': 'default_value'}, 'timeout': '24h', 'status': 'queued'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37/jobs/48
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [48], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/snapshots
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/experiments/37/snapshots?index=0&pageLength=10', 'data': [{'id': 37, 'snapshot': 50, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:44.929125+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.004989+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'get the camera', 'jobs': []}, {'id': 37, 'snapshot': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.004989+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.004989+00:00', 'latestSnapshot': True, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'modded', 'jobs': []}]}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/snapshots/50
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': 37, 'snapshot': 50, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:44.929125+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.004989+00:00', 'latestSnapshot': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'get the camera', 'jobs': []}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/experiments/37/tags
# 2024-07-09 14:50:46 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 14:50:46 [debug    ] Request made.                  data={'ids': [1, 2]} method=PUT url=http://localhost:5000/api/v1/experiments/37/tags
# 2024-07-09 14:50:46 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/37/tags
# 2024-07-09 14:50:46 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}, {'id': 2, 'name': 'nuhuh', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/2'}]
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37/tags
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [1, 2], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data={'ids': [1]} method=POST url=http://localhost:5000/api/v1/experiments/37/tags
# 2024-07-09 14:50:46 [debug    ] Response received.             json=[{'id': 1, 'name': 'youreit', 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/tags/1'}]
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37/tags/1
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37/entrypoints/45
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [45], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/45
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [45], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/37
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'id': [37], 'status': 'Success'}
# 2024-07-09 14:50:46 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/
# 2024-07-09 14:50:46 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/jobs?index=0&pageLength=10', 'data': [{'id': 47, 'snapshot': 65, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:45.999143+00:00', 'lastModifiedOn': '2024-07-09T18:50:45.999143+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'description': 'job description', 'queue': {'snapshotId': 52, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/38/snapshots/52', 'name': 'tensorflow_cpu3'}, 'experiment': {'snapshotId': 51, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/experiments/37/snapshots/51', 'name': 'dioptra v1s first experiment'}, 'entrypoint': {'snapshotId': 62, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/entrypoints/45/snapshots/62', 'name': 'new name'}, 'values': {'parameter_name': 'default_value'}, 'timeout': '24h', 'status': 'started'}]}
# {'index': 0,
#  'isComplete': True,
#  'totalNumResults': 1,
#  'first': '/api/v1/jobs?index=0&pageLength=10',
#  'data': [{'id': 47,
#    'snapshot': 65,
#    'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'},
#    'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'},
#    'createdOn': '2024-07-09T18:50:45.999143+00:00',
#    'lastModifiedOn': '2024-07-09T18:50:45.999143+00:00',
#    'latestSnapshot': True,
#    'hasDraft': False,
#    'tags': [],
#    'description': 'job description',
#    'queue': {'snapshotId': 52,
#     'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'},
#     'url': '/api/v1/queues/38/snapshots/52',
#     'name': 'tensorflow_cpu3'},
#    'experiment': {'snapshotId': 51,
#     'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'},
#     'url': '/api/v1/experiments/37/snapshots/51',
#     'name': 'dioptra v1s first experiment'},
#    'entrypoint': {'snapshotId': 62,
#     'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'},
#     'url': '/api/v1/entrypoints/45/snapshots/62',
#     'name': 'new name'},
#    'values': {'parameter_name': 'default_value'},
#    'timeout': '24h',
#    'status': 'started'}]}

# %%
delete_all()
# Out:
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/experiments/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/experiments?index=0&pageLength=10', 'data': [{'id': 28, 'snapshot': 39, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.642389+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.642389+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'dioptra v1s first experiment', 'description': 'modded', 'entrypoints': [], 'jobs': []}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/experiments/28
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [28], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/entrypoints/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/entrypoints?index=0&pageLength=10', 'data': [{'id': 36, 'snapshot': 49, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:13.003061+00:00', 'lastModifiedOn': '2024-07-09T18:50:13.003061+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'new name', 'description': 'new desc', 'taskGraph': 'task graph?', 'parameters': [{'name': 'parameter_name', 'defaultValue': 'default_value', 'parameterType': 'string'}], 'plugins': [{'id': 30, 'name': 'not_the_first_plugin', 'snapshotId': 41, 'url': '/api/v1/plugins/30/snapshots/41', 'files': [{'id': 33, 'filename': 'the_new_current_file.py', 'snapshotId': 44, 'url': '/api/v1/plugins/30/files/33/snapshots/44'}]}, {'id': 34, 'name': 'not_the_first_plugin2', 'snapshotId': 45, 'url': '/api/v1/plugins/34/snapshots/45', 'files': [{'id': 35, 'filename': 'the_new_current_file.py', 'snapshotId': 46, 'url': '/api/v1/plugins/34/files/35/snapshots/46'}]}], 'queues': [{'id': 29, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/queues/29', 'name': 'tensorflow_cpu3'}]}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/entrypoints/36
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [36], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/jobs/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 0, 'first': '/api/v1/jobs?index=0&pageLength=10', 'data': []}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/plugins/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/plugins?index=0&pageLength=10', 'data': [{'id': 30, 'snapshot': 41, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.728623+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.728623+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin', 'description': 'this plugin does nothing', 'files': [{'id': 33, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/30/files/33', 'filename': 'the_new_current_file.py'}]}, {'id': 34, 'snapshot': 45, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.799664+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.799664+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'not_the_first_plugin2', 'description': 'this plugin does nothing', 'files': [{'id': 35, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'url': '/api/v1/plugins/34/files/35', 'filename': 'the_new_current_file.py'}]}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/30
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [30], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/plugins/34
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [34], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/tags/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 2, 'first': '/api/v1/tags?index=0&pageLength=10', 'data': [{'id': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.694707+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.694707+00:00', 'name': 'youreit'}, {'id': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.704429+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.704429+00:00', 'name': 'nuhuh'}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/tags/1
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [1], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/tags/2
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [2], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/pluginParameterTypes/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 8, 'first': '/api/v1/pluginParameterTypes?index=0&pageLength=10', 'data': [{'id': 1, 'snapshot': 1, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511237+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511237+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'any', 'description': None, 'structure': None}, {'id': 2, 'snapshot': 2, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511524+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511524+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'string', 'description': None, 'structure': None}, {'id': 3, 'snapshot': 3, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511637+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511637+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'integer', 'description': None, 'structure': None}, {'id': 4, 'snapshot': 4, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511747+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511747+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'number', 'description': None, 'structure': None}, {'id': 5, 'snapshot': 5, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511843+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511843+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'boolean', 'description': None, 'structure': None}, {'id': 6, 'snapshot': 6, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 1, 'username': 'testuser', 'url': '/api/v1/users/1'}, 'createdOn': '2024-07-09T17:42:02.511925+00:00', 'lastModifiedOn': '2024-07-09T17:42:02.511925+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'null', 'description': None, 'structure': None}, {'id': 31, 'snapshot': 42, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.748665+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.748665+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'str', 'description': 'str plugin parameter', 'structure': {}}, {'id': 32, 'snapshot': 43, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.760532+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.760532+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'int', 'description': 'int plugin parameter', 'structure': {}}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/1
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/2
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/3
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/4
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/5
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 14:50:39 [error    ] Error code 403 returned.       data=None method=DELETE response={
#     "message": "Forbidden - The plugin parameter type has a read-only lock and cannot be modified."
# }
#  url=http://localhost:5000/api/v1/pluginParameterTypes/6
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/31
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [31], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/pluginParameterTypes/32
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'id': [32], 'status': 'Success'}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=GET url=http://localhost:5000/api/v1/queues/
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'index': 0, 'isComplete': True, 'totalNumResults': 1, 'first': '/api/v1/queues?index=0&pageLength=10', 'data': [{'id': 29, 'snapshot': 40, 'group': {'id': 1, 'name': 'public', 'url': '/api/v1/groups/1'}, 'user': {'id': 5, 'username': 'finalman', 'url': '/api/v1/users/5'}, 'createdOn': '2024-07-09T18:50:12.716503+00:00', 'lastModifiedOn': '2024-07-09T18:50:12.716503+00:00', 'latestSnapshot': True, 'hasDraft': False, 'tags': [], 'name': 'tensorflow_cpu3', 'description': 'for running tensorflow on a cpu'}]}
# 2024-07-09 14:50:39 [debug    ] Request made.                  data=None method=DELETE url=http://localhost:5000/api/v1/queues/29
# 2024-07-09 14:50:39 [debug    ] Response received.             json={'status': 'Success'}

# %%
def filter_data_dict(data, *args):
    data.pop('self', None) # don't need self in dictionary
    for p in args:
        data.pop(p, None) # don't need any of these in dictionary
    return data
def create_user(self, myid, username, password, confirm):
    data = filter_data_dict(locals(), 'myid') # just specify the names of parameters that aren't part of data
    return data
    # requests.post( something )
print(create_user(client, 1234, 'u', 'p', 'p'))
