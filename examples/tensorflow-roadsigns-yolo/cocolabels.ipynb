# %%
import re
import json
from pathlib import Path
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

from scripts.speedlimit_only_dataset import load_xml, extract_roadsigns_annotation_data_from_xml

# %%
roadsigns_annotations = []
for fp in Path("data/Road-Sign-Detection-v2/annotations").glob("*.xml"):
    roadsigns_annotations.append(extract_roadsigns_annotation_data_from_xml(load_xml(fp)[1]))

# %%
def make_coco_categories_list(labels):
    coco_categories_list = [{"id": idx, "name": x} for idx, x in enumerate(labels)]
    categories_mapper = {x["name"]: x["id"] for x in coco_categories_list}

    return coco_categories_list, categories_mapper


def make_coco_images_list_element(data):
    file_name = data["image_file"]
    image_width = int(data["image_width"])
    image_height = int(data["image_height"])
    image_id = re.match(r"\d+?_road(?P<digits>\d+?)\.png", file_name)
    return {"id": int(image_id.groupdict()["digits"]), "width": image_width, "height": image_height, "file_name": file_name, "date_captured": "2022-03-09 00:00:00"}


def make_coco_annotations_list_element_func():
    annotation_id = 0

    def wrapped(data, image_id, categories_mapper):
        nonlocal annotation_id

        for bounding_box in data["image_objects"]:
            category_id = int(categories_mapper[bounding_box["name"]])
            xmin = int(bounding_box["bndbox_xmin"])
            xmax = int(bounding_box["bndbox_xmax"])
            ymin = int(bounding_box["bndbox_ymin"])
            ymax = int(bounding_box["bndbox_ymax"])

            width = xmax - xmin
            height = ymax - ymin

            coco_annotation = {"id": annotation_id, "image_id": image_id, "category_id": category_id, "bbox": [xmin, ymin, width, height], "iscrowd": 0, "area": round(width * height, 1)}
            annotation_id += 1

            yield coco_annotation

    return wrapped

# %%
coco_categories_list, categories_mapper = make_coco_categories_list(["crosswalk", "speedlimit", "stop", "trafficlight"])

# %%
make_coco_annotations_list_element = make_coco_annotations_list_element_func()

coco_images_list = []
coco_annotations_list = []

for annotation in roadsigns_annotations:
    images_list_element = make_coco_images_list_element(annotation)
    coco_images_list.append(images_list_element)

    for annotation_list_element in make_coco_annotations_list_element(annotation, images_list_element["id"], categories_mapper):
        coco_annotations_list.append(annotation_list_element)

coco_images_list = sorted(coco_images_list, key=lambda x: x["id"])
coco_annotations_list = sorted(coco_annotations_list, key=lambda x: (x["image_id"], x["category_id"]))

# %%
coco_info = {"description": "Road Signs Dataset", "version": "2.0", "year": 2020}

# %%
coco_data = {
    "info": coco_info,
    "images": coco_images_list,
    "annotations": coco_annotations_list,
    "categories": coco_categories_list,
}

# %%
with Path("data/Road-Sign-Detection-v2/coco.json").open("wt") as f:
    json.dump(obj=coco_data, fp=f)

# %%
coco_gt = COCO(str(Path("data/Road-Sign-Detection-v2/coco.json")))
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
coco_gt.anns
# Out:
# {343: {'id': 343, 'image_id': 0, 'category_id': 3, 'bbox': [97, 61, 73, 149]},
#  367: {'id': 367,
#   'image_id': 1,
#   'category_id': 3,
#   'bbox': [154, 62, 104, 218]},
#  476: {'id': 476, 'image_id': 2, 'category_id': 3, 'bbox': [143, 270, 30, 82]},
#  477: {'id': 477, 'image_id': 2, 'category_id': 3, 'bbox': [128, 148, 7, 16]},
#  478: {'id': 478, 'image_id': 2, 'category_id': 3, 'bbox': [185, 139, 3, 9]},
#  432: {'id': 432,
#   'image_id': 3,
#   'category_id': 3,
#   'bbox': [178, 134, 57, 127]},
#  663: {'id': 663, 'image_id': 4, 'category_id': 3, 'bbox': [20, 109, 61, 128]},
#  664: {'id': 664,
#   'image_id': 4,
#   'category_id': 3,
#   'bbox': [116, 162, 47, 110]},
#  665: {'id': 665,
#   'image_id': 4,
#   'category_id': 3,
#   'bbox': [189, 189, 43, 106]},
#  628: {'id': 628, 'image_id': 5, 'category_id': 3, 'bbox': [46, 30, 174, 262]},
#  555: {'id': 555, 'image_id': 6, 'category_id': 3, 'bbox': [95, 153, 81, 174]},
#  585: {'id': 585, 'image_id': 7, 'category_id': 3, 'bbox': [120, 145, 39, 73]},
#  586: {'id': 586, 'image_id': 7, 'category_id': 3, 'bbox': [244, 262, 22, 40]},
#  754: {'id': 754, 'image_id': 8, 'category_id': 3, 'bbox': [91, 72, 38, 65]},
#  755: {'id': 755, 'image_id': 8, 'category_id': 3, 'bbox': [243, 102, 32, 62]},
#  702: {'id': 702, 'image_id': 9, 'category_id': 3, 'bbox': [81, 119, 76, 217]},
#  1117: {'id': 1117,
#   'image_id': 10,
#   'category_id': 3,
#   'bbox': [106, 3, 138, 260]},
#  1165: {'id': 1165,
#   'image_id': 11,
#   'category_id': 3,
#   'bbox': [188, 98, 19, 33]},
#  1166: {'id': 1166,
#   'image_id': 11,
#   'category_id': 3,
#   'bbox': [317, 172, 14, 28]},
#  1089: {'id': 1089,
#   'image_id': 12,
#   'category_id': 3,
#   'bbox': [136, 92, 19, 41]},
#  1090: {'id': 1090,
#   'image_id': 12,
#   'category_id': 3,
#   'bbox': [294, 97, 24, 38]},
#  1044: {'id': 1044,
#   'image_id': 13,
#   'category_id': 3,
#   'bbox': [75, 74, 120, 274]},
#  1225: {'id': 1225,
#   'image_id': 14,
#   'category_id': 3,
#   'bbox': [153, 202, 68, 145]},
#  1185: {'id': 1185,
#   'image_id': 15,
#   'category_id': 3,
#   'bbox': [184, 102, 20, 47]},
#  1186: {'id': 1186,
#   'image_id': 15,
#   'category_id': 3,
#   'bbox': [203, 103, 24, 53]},
#  1244: {'id': 1244,
#   'image_id': 16,
#   'category_id': 3,
#   'bbox': [226, 43, 15, 39]},
#  1245: {'id': 1245,
#   'image_id': 16,
#   'category_id': 3,
#   'bbox': [230, 177, 6, 12]},
#  1246: {'id': 1246,
#   'image_id': 16,
#   'category_id': 3,
#   'bbox': [139, 168, 3, 8]},
#  1247: {'id': 1247,
#   'image_id': 16,
#   'category_id': 3,
#   'bbox': [201, 162, 3, 7]},
#  1248: {'id': 1248,
#   'image_id': 16,
#   'category_id': 3,
#   'bbox': [142, 158, 2, 5]},
#  1281: {'id': 1281,
#   'image_id': 17,
#   'category_id': 3,
#   'bbox': [128, 118, 15, 51]},
#  591: {'id': 591,
#   'image_id': 56,
#   'category_id': 2,
#   'bbox': [98, 95, 118, 115]},
#  532: {'id': 532,
#   'image_id': 57,
#   'category_id': 2,
#   'bbox': [24, 35, 260, 239]},
#  694: {'id': 694,
#   'image_id': 58,
#   'category_id': 2,
#   'bbox': [57, 24, 273, 271]},
#  761: {'id': 761,
#   'image_id': 59,
#   'category_id': 2,
#   'bbox': [181, 57, 195, 189]},
#  1019: {'id': 1019,
#   'image_id': 60,
#   'category_id': 2,
#   'bbox': [9, 9, 383, 383]},
#  960: {'id': 960,
#   'image_id': 61,
#   'category_id': 2,
#   'bbox': [52, 28, 294, 269]},
#  877: {'id': 877,
#   'image_id': 62,
#   'category_id': 2,
#   'bbox': [126, 112, 88, 88]},
#  936: {'id': 936,
#   'image_id': 63,
#   'category_id': 2,
#   'bbox': [132, 29, 200, 225]},
#  698: {'id': 698,
#   'image_id': 64,
#   'category_id': 2,
#   'bbox': [55, 11, 327, 267]},
#  758: {'id': 758,
#   'image_id': 65,
#   'category_id': 2,
#   'bbox': [74, 119, 127, 126]},
#  851: {'id': 851,
#   'image_id': 66,
#   'category_id': 2,
#   'bbox': [95, 23, 216, 204]},
#  789: {'id': 789,
#   'image_id': 67,
#   'category_id': 2,
#   'bbox': [112, 64, 147, 152]},
#  626: {'id': 626,
#   'image_id': 68,
#   'category_id': 2,
#   'bbox': [30, 27, 241, 222]},
#  667: {'id': 667,
#   'image_id': 69,
#   'category_id': 2,
#   'bbox': [87, 63, 225, 188]},
#  699: {'id': 699,
#   'image_id': 70,
#   'category_id': 2,
#   'bbox': [148, 70, 140, 102]},
#  700: {'id': 700,
#   'image_id': 70,
#   'category_id': 3,
#   'bbox': [0, 134, 162, 165]},
#  757: {'id': 757,
#   'image_id': 71,
#   'category_id': 2,
#   'bbox': [57, 55, 145, 147]},
#  852: {'id': 852,
#   'image_id': 72,
#   'category_id': 2,
#   'bbox': [267, 169, 133, 103]},
#  786: {'id': 786,
#   'image_id': 73,
#   'category_id': 2,
#   'bbox': [169, 35, 179, 189]},
#  1015: {'id': 1015,
#   'image_id': 74,
#   'category_id': 2,
#   'bbox': [208, 20, 143, 138]},
#  963: {'id': 963, 'image_id': 75, 'category_id': 2, 'bbox': [231, 65, 96, 94]},
#  875: {'id': 875,
#   'image_id': 76,
#   'category_id': 2,
#   'bbox': [28, 91, 133, 142]},
#  937: {'id': 937,
#   'image_id': 77,
#   'category_id': 2,
#   'bbox': [171, 14, 211, 220]},
#  382: {'id': 382, 'image_id': 78, 'category_id': 2, 'bbox': [72, 38, 81, 74]},
#  327: {'id': 327,
#   'image_id': 79,
#   'category_id': 2,
#   'bbox': [75, 21, 237, 220]},
#  528: {'id': 528,
#   'image_id': 80,
#   'category_id': 2,
#   'bbox': [13, 18, 368, 365]},
#  595: {'id': 595,
#   'image_id': 81,
#   'category_id': 2,
#   'bbox': [69, 41, 148, 146]},
#  677: {'id': 677,
#   'image_id': 82,
#   'category_id': 2,
#   'bbox': [58, 55, 150, 151]},
#  612: {'id': 612,
#   'image_id': 83,
#   'category_id': 2,
#   'bbox': [181, 171, 50, 47]},
#  500: {'id': 500, 'image_id': 84, 'category_id': 2, 'bbox': [98, 85, 73, 67]},
#  421: {'id': 421,
#   'image_id': 85,
#   'category_id': 2,
#   'bbox': [80, 145, 150, 147]},
#  325: {'id': 325,
#   'image_id': 86,
#   'category_id': 2,
#   'bbox': [143, 80, 111, 110]},
#  385: {'id': 385,
#   'image_id': 87,
#   'category_id': 2,
#   'bbox': [139, 74, 118, 117]},
#  386: {'id': 386, 'image_id': 87, 'category_id': 2, 'bbox': [246, 212, 9, 9]},
#  939: {'id': 939,
#   'image_id': 88,
#   'category_id': 2,
#   'bbox': [109, 146, 74, 77]},
#  873: {'id': 873, 'image_id': 89, 'category_id': 2, 'bbox': [249, 36, 52, 55]},
#  504: {'id': 504, 'image_id': 90, 'category_id': 2, 'bbox': [172, 94, 77, 80]},
#  417: {'id': 417,
#   'image_id': 91,
#   'category_id': 2,
#   'bbox': [155, 243, 92, 114]},
#  326: {'id': 326,
#   'image_id': 92,
#   'category_id': 2,
#   'bbox': [126, 36, 142, 175]},
#  384: {'id': 384,
#   'image_id': 93,
#   'category_id': 2,
#   'bbox': [179, 24, 175, 172]},
#  524: {'id': 524,
#   'image_id': 94,
#   'category_id': 2,
#   'bbox': [97, 64, 221, 178]},
#  599: {'id': 599,
#   'image_id': 95,
#   'category_id': 2,
#   'bbox': [90, 101, 178, 156]},
#  676: {'id': 676,
#   'image_id': 96,
#   'category_id': 2,
#   'bbox': [209, 58, 117, 120]},
#  613: {'id': 613, 'image_id': 97, 'category_id': 2, 'bbox': [42, 66, 88, 87]},
#  778: {'id': 778,
#   'image_id': 98,
#   'category_id': 2,
#   'bbox': [134, 17, 240, 227]},
#  861: {'id': 861,
#   'image_id': 99,
#   'category_id': 2,
#   'bbox': [40, 33, 182, 179]},
#  912: {'id': 912,
#   'image_id': 100,
#   'category_id': 1,
#   'bbox': [35, 5, 328, 320]},
#  900: {'id': 900,
#   'image_id': 101,
#   'category_id': 1,
#   'bbox': [195, 7, 197, 187]},
#  984: {'id': 984,
#   'image_id': 102,
#   'category_id': 1,
#   'bbox': [37, 38, 206, 207]},
#  986: {'id': 986,
#   'image_id': 103,
#   'category_id': 1,
#   'bbox': [89, 25, 208, 247]},
#  812: {'id': 812,
#   'image_id': 104,
#   'category_id': 1,
#   'bbox': [48, 14, 296, 330]},
#  824: {'id': 824,
#   'image_id': 105,
#   'category_id': 1,
#   'bbox': [27, 146, 254, 231]},
#  724: {'id': 724,
#   'image_id': 106,
#   'category_id': 1,
#   'bbox': [101, 150, 62, 76]},
#  719: {'id': 719,
#   'image_id': 107,
#   'category_id': 1,
#   'bbox': [90, 37, 143, 195]},
#  564: {'id': 564,
#   'image_id': 108,
#   'category_id': 1,
#   'bbox': [174, 128, 12, 11]},
#  576: {'id': 576,
#   'image_id': 109,
#   'category_id': 1,
#   'bbox': [243, 121, 33, 30]},
#  813: {'id': 813,
#   'image_id': 110,
#   'category_id': 1,
#   'bbox': [196, 10, 181, 171]},
#  821: {'id': 821, 'image_id': 111, 'category_id': 1, 'bbox': [35, 92, 66, 67]},
#  727: {'id': 727,
#   'image_id': 112,
#   'category_id': 1,
#   'bbox': [137, 12, 135, 140]},
#  718: {'id': 718,
#   'image_id': 113,
#   'category_id': 1,
#   'bbox': [171, 38, 136, 148]},
#  910: {'id': 910,
#   'image_id': 114,
#   'category_id': 1,
#   'bbox': [254, 32, 69, 69]},
#  907: {'id': 907,
#   'image_id': 115,
#   'category_id': 1,
#   'bbox': [141, 63, 103, 97]},
#  982: {'id': 982,
#   'image_id': 116,
#   'category_id': 1,
#   'bbox': [310, 29, 59, 50]},
#  987: {'id': 987,
#   'image_id': 117,
#   'category_id': 1,
#   'bbox': [224, 32, 65, 71]},
#  462: {'id': 462,
#   'image_id': 118,
#   'category_id': 1,
#   'bbox': [182, 12, 212, 212]},
#  453: {'id': 453,
#   'image_id': 119,
#   'category_id': 1,
#   'bbox': [225, 31, 112, 113]},
#  565: {'id': 565,
#   'image_id': 120,
#   'category_id': 1,
#   'bbox': [79, 20, 151, 209]},
#  574: {'id': 574,
#   'image_id': 121,
#   'category_id': 1,
#   'bbox': [157, 25, 222, 225]},
#  647: {'id': 647,
#   'image_id': 122,
#   'category_id': 0,
#   'bbox': [20, 24, 189, 213]},
#  646: {'id': 646,
#   'image_id': 123,
#   'category_id': 0,
#   'bbox': [151, 73, 120, 122]},
#  470: {'id': 470,
#   'image_id': 124,
#   'category_id': 0,
#   'bbox': [68, 125, 137, 150]},
#  471: {'id': 471,
#   'image_id': 124,
#   'category_id': 3,
#   'bbox': [229, 116, 101, 180]},
#  443: {'id': 443,
#   'image_id': 125,
#   'category_id': 0,
#   'bbox': [15, 26, 153, 131]},
#  353: {'id': 353,
#   'image_id': 126,
#   'category_id': 0,
#   'bbox': [102, 80, 72, 99]},
#  359: {'id': 359,
#   'image_id': 127,
#   'category_id': 0,
#   'bbox': [268, 56, 44, 45]},
#  914: {'id': 914,
#   'image_id': 128,
#   'category_id': 0,
#   'bbox': [216, 50, 125, 140]},
#  898: {'id': 898,
#   'image_id': 129,
#   'category_id': 0,
#   'bbox': [111, 76, 100, 95]},
#  899: {'id': 899,
#   'image_id': 129,
#   'category_id': 3,
#   'bbox': [229, 42, 65, 170]},
#  463: {'id': 463,
#   'image_id': 130,
#   'category_id': 0,
#   'bbox': [162, 30, 19, 20]},
#  464: {'id': 464,
#   'image_id': 130,
#   'category_id': 0,
#   'bbox': [305, 131, 24, 23]},
#  444: {'id': 444, 'image_id': 131, 'category_id': 0, 'bbox': [156, 8, 21, 23]},
#  ...}
