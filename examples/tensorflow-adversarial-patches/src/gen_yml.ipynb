# %%
import importlib.util
import sys
import inspect
import pkgutil
import ast
import os
import yaml
from collections import namedtuple
from dioptra.sdk.utilities.contexts import plugin_dirs
from pathlib import Path
with plugin_dirs(["/c/users/jtsexton/documents/github/dioptra/task-plugins", "/c/users/jtsexton/documents/github/dioptra/examples"]):
    import dioptra_builtins

def import_file_as_module(filepath):
    spec = importlib.util.spec_from_file_location("tmp_module", filepath)
    module = importlib.util.module_from_spec(spec)
    sys.modules["tmp_module"] = module
    spec.loader.exec_module(module)
    return module

def walk_modules(module, st):
    subs = submodules(module)
    if (subs == []):
        st += [module.__name__]
    for i in subs:
        m = importlib.import_module(module.__name__ + '.' + i.name)
        st += walk_modules(m, st)
    return set(st)

def is_mod_function(mod, func):
    return inspect.isfunction(func) and inspect.getmodule(func) == mod

def list_functions(mod):
    return [func.__name__ for func in mod.__dict__.values() 
            if is_mod_function(mod, func)]
    
def generate_stubs(module, plugin_path):
    modules = walk_modules(module, [])
    for m in modules:
        filepth = m.split('.')
        mod = importlib.import_module(m)
        build_stub(mod, plugin_path)
        #write_to_file(fcre, build_stub(mod))

def build_stub(module, plugin_path):
    return generate_functions(module, plugin_path)

def generate_functions(module, plugin_path):
    #print(module)
    ret = []
    fs = list_functions(module)
    for fname in fs:
        #print(module)
        if not fname.startswith('_'):
            func = getattr(module, fname)
            build_task(func, plugin_path)
    return ret
    
def get_function_parameter_names(f):
    #print(getattr(f, "__annotations__", None))
    #print(f.__decorators__)
    argspec = inspect.getfullargspec(f)
    #print(argspec.annotations)

def submodules(m):
    try:
        return pkgutil.iter_modules(m.__path__)
    except:
        return []
        
def get_ret_name():                                                                                                          
    def extract_return(file, fname):                                                                            
        for x in ast.walk(ast.parse(open(file).read())):                                                        
            if not(isinstance(x, ast.FunctionDef)):                                                             
                continue                                                                                        
            if not(x.name == fname):                                                                            
                continue                                                                                        
            for b in x.body:                                                                                    
                if isinstance(b, ast.Return):                                                                   
                    if isinstance(b.value, ast.Name):                                                           
                        yield b.value.id                                                                        
default_types = ["integer", "string", "any", "number"]
defined_types = {}
def create_yml_type_if_not_exists(t):
    global default_types
    global defined_types
    if not isinstance(t,str):
        t = t.__name__ if hasattr(t, '__name__') else str(t)
        #print("here..")
        t = t.replace("typing.", "")
        t = t.replace("pathlib.", "")
        #print(t)
    if (t is None): 
        return ["null"], "null"
    t = t.strip()
    #print("type call:" + t)
    type_lookup = {"int":"integer", "str": "string", "float":"number", "Any":"any"}
    if t in type_lookup.keys():
        return [type_lookup[t]], type_lookup[t]
    elif t in defined_types.keys():
        return [defined_types[t]], t
    else:
        storage_name = ""
        unwrapped = t
        if (t.startswith('Optional')):
            storage_name = "union_null_"
            unwrapped = unwrap(t, 'Optional')
            #print("call1:" + str(t))
            m, name = create_yml_type_if_not_exists(unwrapped)
            storage_name += name
            t_out = {"union": [m, "null"]}
        elif (t.startswith('Dict')):
            storage_name = "mapping_" 
            unwrapped = unwrap(t, 'Dict')
            #print("call2:" + str(t))
            m, name = create_yml_type_if_not_exists(unwrapped)
            #print("m:" + str(m), "name:" + str(name))
            storage_name += name
            t_out = {"mapping": [z for z in m]}
            #print("t_out", t_out)
        elif (t.startswith('Tuple')):
            storage_name = "tuple_" 
            unwrapped = unwrap(t, 'Tuple')
            #print("call2:" + str(t))
            m, name = create_yml_type_if_not_exists(unwrapped)
            storage_name += name
            t_out = {"tuple": [z for z in m]}
        elif (t.startswith('Union')):
            storage_name = "union_"
            unwrapped = unwrap(t, 'Union')
            #print("call3:" + str(t))
            m, name = create_yml_type_if_not_exists(unwrapped)
            storage_name += name
            t_out = {"union": [z for z in m]}
        elif (t.startswith('List')):
            storage_name = "list_"
            unwrapped = unwrap(t, 'List')
            #print("call4:" + str(t))
            m, name = create_yml_type_if_not_exists(unwrapped)
            #print("m:" + str(m), "name:" + str(name))
            storage_name += name
            t_out = {"list": m}
        else:
            if ',' in unwrapped and (unwrapped.find(',') < unwrapped.find('[') or unwrapped.find('[') < 0):
                types = unwrapped.split(', ')
                first_in_list = unwrapped[:unwrapped.find(',')]
                rest_of_list = unwrapped[unwrapped.find(', ')+1:]
                #print("call5:" + str(t))
                first_t, first_name = create_yml_type_if_not_exists(first_in_list)
                #print("call6:" + str(t))
                rest_t, rest_name = create_yml_type_if_not_exists(rest_of_list)
                #print(rest_t, rest_name)
                ret1= first_t + rest_t
                ret2= storage_name + first_name + '_' + rest_name
                #print("rets:", ret1, ret2)
                return ret1, ret2
            else:
                t_out = t.lower()
                storage_name=t.lower()
                #print("ERROR:" + unwrapped)
        storage_name.replace('.', '_')
        defined_types[storage_name] = t_out
        return [t_out], storage_name
def unwrap(s, s2):
    return s[len(s2 + '['):-1]
def generate_yml_func(): 
    task_list = {}
    ret = {"tasks":task_list}
def get_plugin_name(f):
    return f.__name__
def get_plugin_inputs(f):
    argspec = inspect.getfullargspec(f)
    #print(argspec)
    defaults = argspec.defaults
    #print(defaults)
    num_def = len(defaults) if defaults is not None else 0
    #print(num_def)
    annotations = argspec.annotations
    annotations = {i:annotations[i] for i in annotations if i!='return'}
    num_param = len(annotations) if annotations is not None else 0
    ret = []
    for m in annotations:
        #print( "mastercall:" + str(m), str(annotations[m]))
        q, type_name = create_yml_type_if_not_exists(annotations[m])
        #print("type:" + str(q))
        if (num_param - num_def > 0):
            ret += [{m:type_name}]
        else:
            ret += [{"name":m, "type":type_name, "required": False}]
        num_param-=1
    return ret
def get_plugin_outputs(f):
    argspec = inspect.getfullargspec(f)
    #print(argspec)
    returns = argspec.annotations['return']
    ret = []
    #print(returns)
    if not isinstance(returns, str):
        returns = returns.__name__ if hasattr(returns, '__name__') else str(returns)
        returns = returns.replace("typing.", "")
        returns = returns.replace("pathlib.", "")

    if returns.startswith("Tuple"):
        returns = unwrap(returns, "Tuple")
        returns = returns.split(', ')
        m = 0
        for b in returns:
            m += 1
            q, type_name = create_yml_type_if_not_exists(b)    
            ret += [{"ret" + str(m):type_name}]
    else:
        q, type_name = create_yml_type_if_not_exists(returns)
        ret = {"ret":type_name}
    return ret
def build_task(f, plugin_path):
    f = inspect.unwrap(f)
    argspec = inspect.getfullargspec(f)
    if (len(argspec.annotations) > 0):
        ret = {}
        fdesc = {}
        fdesc["plugin"] = plugin_path + '.' + get_plugin_name(f)
        fdesc["inputs"] = get_plugin_inputs(f)
        fdesc["outputs"] = get_plugin_outputs(f)
        if (fdesc["inputs"] == []):
            del fdesc["inputs"]
        #print (type(fdesc["outputs"]))
        if (isinstance(fdesc["outputs"], dict) and fdesc["outputs"]["ret"] == "none"):
            del fdesc["outputs"]
        ret[f.__name__] = fdesc
        print(yaml.dump(ret))
    
def walk_example_plugins(directory):
    import os
    for root, dirs, files in os.walk(directory, topdown=False):
        for name in files:
            if (name.endswith(".py")):
                path = os.path.join(root, name)
                plugin_path = path.replace('.py','')
                plugin_path = plugin_path.replace(directory, '')
                plugin_path = plugin_path.replace('/', '.')
                #print(plugin_path)
                if (".venv" not in path and '.ipynb' not in path):
                    try: 
                        mod = import_file_as_module(path)
                        generate_stubs(mod, plugin_path)
                    except:
                        pass
        #for name in dirs:
        #print(os.path.join(root, name))

def generate_yml_defs(directory):
    pass
walk_example_plugins("/c/users/jtsexton/documents/github/dioptra/examples/task-plugins/")
#generate_stubs(dioptra_builtins)
# Out:
# create_adversarial_fgm_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: eps
#     required: false
#     type: number
#   - name: eps_step
#     required: false
#     type: number
#   - name: minimal
#     required: false
#     type: number
#   - name: norm
#     required: false
#     type: number
#   - name: target_index
#     required: false
#     type: integer
#   - name: targeted
#     required: false
#     type: bool
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_fgm_plugins.attacks_fgm.create_adversarial_fgm_dataset
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   - name: rescale
#     required: false
#     type: number
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_fgm_plugins.data_tensorflow.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_fgm_plugins.data_tensorflow.get_n_classes_from_directory_iterator
#
# rescale:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_fgm_plugins.data_tensorflow.rescale
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - dataset_name: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_fgm_plugins.defenses_image_preprocessing.create_defended_dataset
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.estimators_keras_classifiers.vgg16
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_fgm_plugins.registry_art.load_wrapped_tensorflow_keras_classifier
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_fgm_plugins.tensorflow.register_init_model
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.load_wrapped_tensorflow_keras_classifier
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.vgg16
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   - name: rescale
#     required: false
#     type: number
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.get_n_classes_from_directory_iterator
#
# rescale:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.rescale
#
# create_adversarial_fgm_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: eps
#     required: false
#     type: number
#   - name: eps_step
#     required: false
#     type: number
#   - name: minimal
#     required: false
#     type: number
#   - name: norm
#     required: false
#     type: number
#   - name: target_index
#     required: false
#     type: integer
#   - name: targeted
#     required: false
#     type: bool
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.create_adversarial_fgm_dataset
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.register_init_model
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - dataset_name: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_fgm_plugins.__init__.create_defended_dataset
#
# create_adversarial_patches:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - patch_target: integer
#   - num_patch: integer
#   - num_patch_samples: integer
#   - rotation_max: number
#   - scale_min: number
#   - scale_max: number
#   - learning_rate: number
#   - max_iter: integer
#   - patch_shape: tuple_
#   - name: rescale
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.attacks_patch.create_adversarial_patches
#
# create_adversarial_patch_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - patch_dir: string
#   - patch_application_rate: number
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - patch_shape: tuple_
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: patch_deployment_method
#     required: false
#     type: string
#   - name: patch_scale
#     required: false
#     type: number
#   - name: rotation_max
#     required: false
#     type: number
#   - name: scale_min
#     required: false
#     type: number
#   - name: scale_max
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.attacks_patch.create_adversarial_patch_dataset
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: rescale
#     required: false
#     type: number
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_patch_plugins.data_tensorflow.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_patch_plugins.data_tensorflow.get_n_classes_from_directory_iterator
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.defenses_image_preprocessing.create_defended_dataset
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.estimators_keras_classifiers.vgg16
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple_
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_patch_plugins.registry_art.load_wrapped_tensorflow_keras_classifier
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_patch_plugins.tensorflow.register_init_model
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_patch_plugins.__init__.load_wrapped_tensorflow_keras_classifier
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_patch_plugins.__init__.vgg16
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   - name: rescale
#     required: false
#     type: number
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_patch_plugins.__init__.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_patch_plugins.__init__.get_n_classes_from_directory_iterator
#
# rescale:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_patch_plugins.__init__.rescale
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_patch_plugins.__init__.register_init_model
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - dataset_name: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.__init__.create_defended_dataset
#
# create_adversarial_patches:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - patch_target: integer
#   - num_patch: integer
#   - num_patch_samples: integer
#   - rotation_max: number
#   - scale_min: number
#   - scale_max: number
#   - learning_rate: number
#   - max_iter: integer
#   - patch_shape: tuple_
#   - name: rescale
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.__init__.create_adversarial_patches
#
# create_adversarial_patch_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - patch_dir: string
#   - patch_application_rate: number
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - patch_shape: tuple_
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: patch_deployment_method
#     required: false
#     type: string
#   - name: patch_scale
#     required: false
#     type: number
#   - name: rotation_max
#     required: false
#     type: number
#   - name: scale_min
#     required: false
#     type: number
#   - name: scale_max
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_patch_plugins.__init__.create_adversarial_patch_dataset
#
# create_adv_embedding_model:
#   inputs:
#   - model: model
#   - training_ds: directoryiterator
#   - target_class_id: integer
#   - feature_layer_index: integer
#   - poison_fraction: number
#   - regularization_factor: number
#   - learning_rate: number
#   - batch_size: integer
#   - epochs: integer
#   - discriminator_layer_1_size: integer
#   - discriminator_layer_2_size: integer
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.attacks_poison.create_adv_embedding_model
#
# create_adversarial_poison_data:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: target_class
#     required: false
#     type: string
#   - name: label_type
#     required: false
#     type: string
#   - name: poison_fraction
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.attacks_poison.create_adversarial_poison_data
#
# create_adversarial_clean_poison_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: eps
#     required: false
#     type: number
#   - name: eps_step
#     required: false
#     type: number
#   - name: max_iter
#     required: false
#     type: integer
#   - name: norm
#     required: false
#     type: number
#   - name: label_type
#     required: false
#     type: string
#   - name: poison_fraction
#     required: false
#     type: number
#   - name: target_index
#     required: false
#     type: integer
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.attacks_poison.create_adversarial_clean_poison_dataset
#
# select_rescale_value:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_poisoning_plugins.datasetup.select_rescale_value
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: rescale
#     required: false
#     type: number
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   - name: set_to_max_size
#     required: false
#     type: bool
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_poisoning_plugins.data_tensorflow.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_poisoning_plugins.data_tensorflow.get_n_classes_from_directory_iterator
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.defenses_image_preprocessing.create_defended_dataset
#
# create_Madry_PGD_model:
#   inputs:
#   - model: model
#   - training_ds: directoryiterator
#   - eps: number
#   - eps_step: number
#   - learning_rate: number
#   - batch_size: integer
#   - epochs: integer
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.defenses_training.create_Madry_PGD_model
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.estimators_keras_classifiers.vgg16
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple_
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_poisoning_plugins.registry_art.load_wrapped_tensorflow_keras_classifier
#
# deploy_poison_images:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - poison_deployment_method: string
#   - num_poisoned_images: integer
#   outputs:
#     ret: string
#   plugin: dioptra_custom.custom_poisoning_plugins.registry_art.deploy_poison_images
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.tensorflow.register_init_model
#
# load_wrapped_tensorflow_keras_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   - name: clip_values
#     required: false
#     type: tuple
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   outputs:
#     ret: kerasclassifier
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.load_wrapped_tensorflow_keras_classifier
#
# create_adv_embedding_model:
#   inputs:
#   - model: model
#   - training_ds: directoryiterator
#   - target_class_id: integer
#   - feature_layer_index: integer
#   - poison_fraction: number
#   - regularization_factor: number
#   - learning_rate: number
#   - batch_size: integer
#   - epochs: integer
#   - discriminator_layer_1_size: integer
#   - discriminator_layer_2_size: integer
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_adv_embedding_model
#
# create_adversarial_poison_data:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: target_class
#     required: false
#     type: string
#   - name: label_type
#     required: false
#     type: string
#   - name: poison_fraction
#     required: false
#     type: number
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_adversarial_poison_data
#
# create_adversarial_clean_poison_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: eps
#     required: false
#     type: number
#   - name: eps_step
#     required: false
#     type: number
#   - name: max_iter
#     required: false
#     type: integer
#   - name: norm
#     required: false
#     type: number
#   - name: label_type
#     required: false
#     type: string
#   - name: poison_fraction
#     required: false
#     type: number
#   - name: target_index
#     required: false
#     type: integer
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_adversarial_clean_poison_dataset
#
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - name: loss
#     required: false
#     type: string
#   - name: training
#     required: false
#     type: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.init_classifier
#
# shallow_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.shallow_net
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.le_net
#
# alex_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.alex_net
#
# resnet50:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.resnet50
#
# vgg16:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   - training: bool
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.vgg16
#
# create_Madry_PGD_model:
#   inputs:
#   - model: model
#   - training_ds: directoryiterator
#   - eps: number
#   - eps_step: number
#   - learning_rate: number
#   - batch_size: integer
#   - epochs: integer
#   - optimizer: optimizer
#   - metrics: list_union_metric_functiontype
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_Madry_PGD_model
#
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - subset: union_null_string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: imagenet_preprocessing
#     required: false
#     type: bool
#   - name: rescale
#     required: false
#     type: number
#   outputs:
#     ret: directoryiterator
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: directoryiterator
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.get_n_classes_from_directory_iterator
#
# rescale:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.rescale
#
# select_rescale_value:
#   inputs:
#   - imagenet_preprocessing: bool
#   outputs:
#     ret: number
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.select_rescale_value
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.register_init_model
#
# create_defended_dataset:
#   inputs:
#   - data_dir: string
#   - dataset_name: string
#   - def_data_dir: union_string_path
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: def_type
#     required: false
#     type: string
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.custom_poisoning_plugins.__init__.create_defended_dataset
#
# get_callback:
#   inputs:
#   - callback_name: string
#   outputs:
#     ret: callback
#   plugin: dioptra_custom.evaluation.import_keras.get_callback
#
# get_metric:
#   inputs:
#   - metric_name: string
#   outputs:
#     ret: union_metric_functiontype
#   plugin: dioptra_custom.evaluation.import_keras.get_metric
#
# get_optimizer:
#   inputs:
#   - optimizer_name: string
#   outputs:
#     ret: optimizer
#   plugin: dioptra_custom.evaluation.import_keras.get_optimizer
#
# add_model_to_registry:
#   inputs:
#   - name: string
#   - model_dir: string
#   outputs:
#     ret: union_null_modelversion
#   plugin: dioptra_custom.evaluation.mlflow.add_model_to_registry
#
# get_experiment_name:
#   outputs:
#     ret: string
#   plugin: dioptra_custom.evaluation.mlflow.get_experiment_name
#
# register_init_model:
#   outputs:
#     ret: model
#   plugin: dioptra_custom.evaluation.__init__.register_init_model
#
# add_model_to_registry:
#   inputs:
#   - name: string
#   - model_dir: string
#   outputs:
#     ret: union_null_modelversion
#   plugin: dioptra_custom.evaluation.__init__.add_model_to_registry
#
# get_experiment_name:
#   outputs:
#     ret: string
#   plugin: dioptra_custom.evaluation.__init__.get_experiment_name
#
# get_callback:
#   inputs:
#   - callback_name: string
#   outputs:
#     ret: callback
#   plugin: dioptra_custom.evaluation.__init__.get_callback
#
# get_metric:
#   inputs:
#   - metric_name: string
#   outputs:
#     ret: union_metric_functiontype
#   plugin: dioptra_custom.evaluation.__init__.get_metric
#
# get_optimizer:
#   inputs:
#   - optimizer_name: string
#   outputs:
#     ret: optimizer
#   plugin: dioptra_custom.evaluation.__init__.get_optimizer
#
# infer_model_inversion:
#   inputs:
#   - keras_classifier: kerasclassifier
#   - adv_data_dir: union_string_path
#   - name: batch_size
#     required: false
#     type: integer
#   - name: classes
#     required: false
#     type: integer
#   - name: max_iter
#     required: false
#     type: integer
#   - name: window_length
#     required: false
#     type: integer
#   - name: threshold
#     required: false
#     type: number
#   - name: learning_rate
#     required: false
#     type: number
#   plugin: dioptra_custom.model_inversion.modelinversion.infer_model_inversion
#
# infer_model_inversion:
#   inputs:
#   - keras_classifier: kerasclassifier
#   - adv_data_dir: union_string_path
#   - name: batch_size
#     required: false
#     type: integer
#   - name: classes
#     required: false
#     type: integer
#   - name: max_iter
#     required: false
#     type: integer
#   - name: window_length
#     required: false
#     type: integer
#   - name: threshold
#     required: false
#     type: number
#   - name: learning_rate
#     required: false
#     type: number
#   plugin: dioptra_custom.model_inversion.__init__.infer_model_inversion
#
# create_pt_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: th
#     required: false
#     type: integer
#   - name: es
#     required: false
#     type: integer
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.pixel_threshold.pixelthreshold.create_pt_dataset
#
# create_pt_dataset:
#   inputs:
#   - data_dir: string
#   - adv_data_dir: union_string_path
#   - keras_classifier: kerasclassifier
#   - image_size: tuple_integer_integer_integer
#   - name: distance_metrics_list
#     required: false
#     type: union_null_list_tuple_string_callable[..., np.ndarray]
#   - name: rescale
#     required: false
#     type: number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   - name: th
#     required: false
#     type: integer
#   - name: es
#     required: false
#     type: integer
#   outputs:
#     ret: pd.dataframe
#   plugin: dioptra_custom.pixel_threshold.__init__.create_pt_dataset
#
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=tensorflow
# add_model_to_registry:
#   inputs:
#   - active_run: mlflowrun
#   - name: string
#   - model_dir: string
#   outputs:
#     ret: union_null_modelversion
#   plugin: dioptra_custom.pytorch_d2.registry_mlflow_detectron2.add_model_to_registry
#
# get_experiment_name:
#   inputs:
#   - active_run: mlflowrun
#   outputs:
#     ret: string
#   plugin: dioptra_custom.pytorch_d2.registry_mlflow_detectron2.get_experiment_name
#
# load_pytorch_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.pytorch_d2.registry_mlflow_detectron2.load_pytorch_classifier
#
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=torchvision
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=torch
# create_image_dataset:
#   inputs:
#   - data_dir: string
#   - image_size: tuple_integer_integer_integer
#   - seed: integer
#   - name: validation_split
#     required: false
#     type: union_null_number
#   - name: batch_size
#     required: false
#     type: integer
#   - name: label_mode
#     required: false
#     type: string
#   outputs:
#   - ret1: any
#   - ret2: any
#   plugin: dioptra_custom.pytorch_mi.data_pytorch.create_image_dataset
#
# get_n_classes_from_directory_iterator:
#   inputs:
#   - ds: dataloader
#   outputs:
#     ret: integer
#   plugin: dioptra_custom.pytorch_mi.data_pytorch.get_n_classes_from_directory_iterator
#
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=torch
# init_classifier:
#   inputs:
#   - model_architecture: string
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.pytorch_mi.estimators_pytorch_classifiers.init_classifier
#
# le_net:
#   inputs:
#   - input_shape: tuple_integer_integer_integer
#   - n_classes: integer
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.pytorch_mi.estimators_pytorch_classifiers.le_net
#
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=torch
# get_optimizer:
#   inputs:
#   - optimizer_name: string
#   outputs:
#     ret: optimizer
#   plugin: dioptra_custom.pytorch_mi.import_pytorch.get_optimizer
#
# 2023-09-28 13:09:14 [warning  ] Unable to import one or more optional packages, functionality may be reduced package=tensorflow
# add_model_to_registry:
#   inputs:
#   - active_run: mlflowrun
#   - name: string
#   - model_dir: string
#   outputs:
#     ret: union_null_modelversion
#   plugin: dioptra_custom.pytorch_mi.registry_mlflow_pytorch.add_model_to_registry
#
# get_experiment_name:
#   inputs:
#   - active_run: mlflowrun
#   outputs:
#     ret: string
#   plugin: dioptra_custom.pytorch_mi.registry_mlflow_pytorch.get_experiment_name
#
# load_pytorch_classifier:
#   inputs:
#   - name: string
#   - version: integer
#   outputs:
#     ret: sequential
#   plugin: dioptra_custom.pytorch_mi.registry_mlflow_pytorch.load_pytorch_classifier

# %%
import tensorflow
# Out:
# 2023-09-19 11:00:31.754524: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-19 11:00:31.986232: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-19 11:00:33.291342: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-19 11:00:33.295364: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 11:01:19.389601: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
